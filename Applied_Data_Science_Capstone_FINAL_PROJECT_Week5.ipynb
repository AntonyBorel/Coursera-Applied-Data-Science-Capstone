# %% [markdown]
# ***

# %% [markdown]
# <h1 align="center"><font color=darkblue>BUDAPEST HARMONY</font></h1>

# %% [markdown]
# ***

# %% [markdown]
# <h2 align="center">Where should you install your startup headquarter to guarantee a pleasant working and rest environment to your collaborators?</h2>

# %% [markdown]
# ***

# %% [markdown]
# ## Table of contents
# * [1.Introduction: Business Problem](#introduction)
# * [2. Data](#data)
#  * [2.1 Building of the venues dataset](#buildvenues)
#    * [2.1.1 Budapest city center](#budapest)
#    * [2.1.2 Official (thermal) baths of Budapest](#baths)
#    * [2.1.3 Vegetarian or vegan restaurants](#veg)
#    * [2.1.4 Hungarian food restaurants](#hungarian)
#    * [2.1.5 Fitness centers](#sport)
#    * [2.1.6 Conference rooms](#conference)
#    * [2.1.7 Libraries](#libraries)
#    * [2.1.8 Concatenate venues datasets](#venuesdata)
#  * [2.2 Building of the duration to airport dataset](#buildduration)
# * [3. Methodology](#methodology)
# * [4. Results](#results)
#  * [4.1 Exploration of geospatial data](#geospatial)
#  * [4.2 Clustering of geospatial, distance and duration to airport data](#clustering)
#  * [4.3 Visualization of the suggested area and description of venues accessibilities](#kalvin)
# * [5. Discussion](#discussion)
# * [6. Conclusion](#conclusion)

# %% [markdown]
# *Libraries import and setup:*

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranforming json file into a pandas dataframe library
from sklearn.cluster import DBSCAN # import DBSCAN from clustering stage
from sklearn.preprocessing import StandardScaler # standardize data
from unidecode import unidecode # Hungarian characters conversion to the closest representation in ascii text

import sklearn.utils # used to set seed
import json # work with JSON data
import requests # library to handle requests
import pandas as pd # library for data analysis
import numpy as np # library to handle data in a vectorized manner
import folium # library for maps
import matplotlib.cm as cm # library for plotting

# Observe maximum 100 rows:
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## 1. Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# An Hungarian startup is quickly growing. Its current headquarter is a small room in the countryside, located 4 hours from the capital city, Budapest. **The company needs to relocate its headquarters in Budapest** in a larger space as the collaborators are getting more numerous and they have to go abroad and host partners from abroad to maintain and increase the international growth of the company. The two founders of the company pays particular attention to the **well-being of their collaborators and their partners visiting the company**. Therefore, the choice of their new headquarter will be highly related to the accessibility of facilities allowing relaxing and/or facilitating the **daily harmony between professional and personal activities**.
#
# The startup founders are thus **asking for suggestion about where to settle their new headquarter**. The location of the new headquarters must meet the following criteria:
# - one of the famous **official (thermal) bath** from Budapest should be no more than **1km** (as the crow flies) from the headquarter
# - a **conference center** should be no more than **1km** (as the crow flies) from the headquarter
# - a **library** should be no more than **1km** (as the crow flies) from the headquarter
# - at least one restaurant providing **vegetarian or vegan food** and one restaurant providing **hungarian food** should be no more than **500m** (as the crow flies) from the headquarter
# - a **fitness center** should be no more than **500m** (as the crow flies) from the headquarter
# - location from the Liszt Ferenc **International Airport** of Budapest is also important. Going to the airport should take **less than 45 minutes** by car/taxi.
#
# In case of more than one location responding to all the criteria, the duration of the trip from/to the airport could be used to hierarchize these locations.

# %% [markdown]
# ## 2. Data <a name="data"></a>

# %% [markdown]
# Based on the request from the startup we have to gather geospatial data as well as name and categories of venues in Budapest in order to find a solution which meets the given criteria.
#
# **Geopy** will be used to obtain **latitude and longitude of Budapest city and Budapest international airport**. It will also be used to get coordinates of the suggested places for the headquarter if these places can be precise enough.
#
# The given distance for the first 5 criteria are "as the crow flies" so we will use **Foursquare API** (https://developer.foursquare.com/) to get coordinates of the venues and **latitude and longitude associated with name and categories** of each of them. However, a maximum duration for the trip by car/taxi to the airport is given, this information cannot be obtain through Foursquare. So, to obtain distance and **trip duration to the airport** we will use **MapQuest API** (https://developer.mapquest.com/).
#
# The startup founders precise that they wish to be close to an "official (thermal) bath" of Budapest. So we will consider only official baths, results from Foursquare will have to be filtered with this purpose. Based on the official website of Budapest baths (http://www.budapestgyogyfurdoi.hu/gyogyfurdok-es-strandok) we know that there are **12 official baths**: Széchenyi, Gellért, Rudas, Lukács, Király, Dandár, Paskál, Palatinus, Csillaghegy, Pesterzsébet, Római and Pünkösdfürdő.

# %% [markdown]
# ### 2.1 Building of the venues dataset <a name="buildvenues"></a>

# %% [markdown]
# #### 2.1.1 Budapest city center <a name="budapest"></a>

# %% [markdown]
# **We use geopy library to get the coordinates of Budapest (Hungary)**

# %%
address = 'Budapest, Hungary'

geolocator = Nominatim(user_agent="bud_explorer")
location = geolocator.geocode(address)
latBUD = location.latitude
longBUD = location.longitude
print('The geograpical coordinate of Budapest are {}, {}.'.format(latBUD, longBUD))
# Out:
# The geograpical coordinate of Budapest are 47.4983815, 19.0404707.

# %% [markdown]
# #### 2.1.2 Official (thermal) baths of Budapest <a name="baths"></a>

# %% [markdown]
# We first set a hidden cell with our Foursquare API "client ID" and "Client secret"

# %%
# @hidden_cell
CLIENT_ID = 'KBS4CBNEO0UWR2RSVTJQBD4JXVC2UCCH2ZPXMFW103FFEEJT' # your Foursquare ID
CLIENT_SECRET = 'RNGPZ3WG34QOQQS30WEMKSDPQZ5OEOXHO5KG5BYZ3FJMQVRM' # your Foursquare Secret

# %% [markdown]
# **We search for the Budapest official thermal baths using Foursquare API**

# %% [markdown]
# In order to obtain data from all the official thermal baths of Budapest we need a radius of 12km. We give a limit number of results of 100 as many thermal baths, which are not considered as official city bath, exist in Budapest. Therefore, we expect to get the 12 baths we are looking for within this set of results.
# We performed several tests in order to get better results from Foursquare, using different types of queries and combined queries, but none of them is giving the 12 baths at once. Indeed, these baths are classified in different categories, with no string in common in their name, etc., and it seems that the API in not very stable. Best results were obtained first searching for "Gyógyfürdő" (hungarian term for "thermal bath" or "spa") and then searching for "Strand" (hungarian term for "pool" or "water park").
# We will keep the same radius and limit for the queries concerning the other venues.

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100
search_query = 'Gyógyfürdő' #means thermal bath in Hungarian
categoryID = '4bf58dd8d48988d1ed941735'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, categoryID, radius, LIMIT)

resultsTB = requests.get(url).json()

# assign relevant part of JSON to venues
venuesTB = resultsTB['response']['venues']

# tranform venues into a dataframe
dfTB = pd.json_normalize(venuesTB)

# %% [markdown]
# **Keep only columns that include venue name, and anything that is associated with location**

# %%
filtered_columns = ['name', 'categories'] + [col for col in dfTB.columns if col.startswith('location.')] + ['id']
dfTB_filtered = dfTB.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfTB_filtered['categories'] = dfTB_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfTB_filtered.columns = [column.split('.')[-1] for column in dfTB_filtered.columns]

# %% [markdown]
# **We extract only data with category "Spa"**

# %%
DataSpa = dfTB_filtered[dfTB_filtered['categories']=='Spa']
DataSpa.reset_index(drop=True, inplace=True)
DataSpa
# Out:
#                                  name categories                 address  \
# 0          Rudas Gyógyfürdő és Uszoda        Spa        Döbrentei tér 9.
# 1  Szent Gellért Gyógyfürdő és Uszoda        Spa        Kelenhegyi út 4.
# 2   Szent Lukács Gyógyfürdő és Uszoda        Spa   Frankel Leó u. 25-29.
# 3                   Dandár Gyógyfürdő        Spa            Dandár u. 3.
# 4      Széchenyi Gyógyfürdő és Uszoda        Spa  Állatkerti körút 9-11.
# 5                   Király Gyógyfürdő        Spa               Fő u. 84.
#
#           crossStreet        lat        lng  \
# 0  Szent Gellért rkp.  47.489188  19.047761
# 1                 NaN  47.483917  19.052256
# 2                 NaN  47.518829  19.081770
# 3                 NaN  47.476337  19.071061
# 4                 NaN  47.518302  19.082394
# 5            Kacsa u.  47.510608  19.038185
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 47.48918773695423...      1161       1013  HU
# 1  [{'label': 'display', 'lat': 47.4839168757732,...      1838       1118  HU
# 2  [{'label': 'display', 'lat': 47.518829, 'lng':...      3850       1023  HU
# 3  [{'label': 'display', 'lat': 47.47633741284682...      3364       1095  HU
# 4  [{'label': 'display', 'lat': 47.51830206635792...      3854       1146  HU
# 5  [{'label': 'display', 'lat': 47.51060830660980...      1371       1027  HU
#
#        city     state       country  \
# 0  Budapest  Budapest  Magyarország
# 1  Budapest  Budapest  Magyarország
# 2  Budapest  Budapest  Magyarország
# 3  Budapest  Budapest  Magyarország
# 4  Budapest  Budapest  Magyarország
# 5  Budapest  Budapest  Magyarország
#
#                                     formattedAddress neighborhood  \
# 0  [Budapest, Döbrentei tér 9. (Szent Gellért rkp...          NaN
# 1   [Budapest, Kelenhegyi út 4., 1118, Magyarország]          NaN
# 2  [Budapest, Frankel Leó u. 25-29., 1023, Magyar...          NaN
# 3       [Budapest, Dandár u. 3., 1095, Magyarország]          NaN
# 4  [Budapest, Állatkerti körút 9-11., 1146, Magya...   Városliget
# 5  [Budapest, Fő u. 84. (Kacsa u.), 1027, Magyaro...          NaN
#
#                          id
# 0  4b2a3b92f964a52058a624e3
# 1  4b2a3f25f964a52079a624e3
# 2  4b7ec53ef964a52012fe2fe3
# 3  4e4131aea809968085325a0f
# 4  4bb6452c2f70c9b606278530
# 5  4c756513ff1fb60c5915f6a7

# %% [markdown]
# We got 6 of the 12 official Budapest baths.

# %% [markdown]
# **Search for the Budapest official water park or pool**

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100

search_query = 'Strand' 
categoryID = '4bf58dd8d48988d1ed941735'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, categoryID, radius, LIMIT)

resultsST = requests.get(url).json()

# assign relevant part of JSON to venues
venuesST = resultsST['response']['venues']

# tranform venues into a dataframe
dfST = pd.json_normalize(venuesST)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dfST.columns if col.startswith('location.')] + ['id']
dfST_filtered = dfST.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfST_filtered['categories'] = dfST_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfST_filtered.columns = [column.split('.')[-1] for column in dfST_filtered.columns]

pd.set_option('display.max_rows', None)

# %% [markdown]
# **We extract only data with category "Water Park" or "Pool"**

# %%
DataPoolTemp = dfST_filtered[dfST_filtered['categories'].isin(['Water Park', 'Pool']) ]
DataPoolTemp.reset_index(drop=True, inplace=True)
DataPoolTemp
# Out:
#                                              name  categories        lat  \
# 0                           Palatinus Strandfürdő  Water Park  47.529170
# 1       Dagály Termálfürdő, Strandfürdő és Uszoda  Water Park  47.538782
# 2   Budaörs Városi Uszoda, Sportcsarnok és Strand        Pool  47.455988
# 3                    Paskál Gyógy- és Strandfürdő  Water Park  47.520571
# 4                                     BVSC strand        Pool  47.520624
# 5                                   Óbudai Strand        Pool  47.552394
# 6                               Római Strandfürdő        Pool  47.574811
# 7                            Pünkösdfürdői Strand        Pool  47.594627
# 8                              Csillaghegy strand        Pool  47.585284
# 9                                 Tungsram Strand        Pool  47.586423
# 10                                    Duna Strand        Pool  47.590283
# 11                                 Csepeli Strand  Water Park  47.407222
# 12  Pesterzsébeti Jódos-Sós Gyógy- És Strandfürdő        Pool  47.435448
# 13             Csillaghegyi Strandfürdő és Uszoda        Pool  47.585979
# 14                  Újhegyi Uszoda és Strandfürdő        Pool  47.466747
#
#           lng                                     labeledLatLngs  distance  \
# 0   19.046946  [{'label': 'display', 'lat': 47.52916959486753...      3461
# 1   19.061464  [{'label': 'display', 'lat': 47.53878223302512...      4766
# 2   18.969628  [{'label': 'display', 'lat': 47.45598830916391...      7119
# 3   19.127469  [{'label': 'display', 'lat': 47.52057142517493...      6992
# 4   19.089959  [{'label': 'display', 'lat': 47.520624, 'lng':...      4469
# 5   19.027236  [{'label': 'display', 'lat': 47.55239390869436...      6094
# 6   19.052087  [{'label': 'display', 'lat': 47.57481146475501...      8552
# 7   19.067900  [{'label': 'display', 'lat': 47.59462716397096...     10910
# 8   19.041588  [{'label': 'display', 'lat': 47.58528354752551...      9674
# 9   19.077983  [{'label': 'display', 'lat': 47.58642285955192...     10197
# 10  19.083352  [{'label': 'display', 'lat': 47.59028273949961...     10725
# 11  19.100471  [{'label': 'display', 'lat': 47.40722207338957...     11107
# 12  19.090965  [{'label': 'display', 'lat': 47.435448, 'lng':...      7969
# 13  19.042334  [{'label': 'display', 'lat': 47.58597927264667...      9752
# 14  19.166867  [{'label': 'display', 'lat': 47.46674749761492...     10140
#
#     cc       country                                   formattedAddress  \
# 0   HU  Magyarország       [Budapest, Margitsziget, 1138, Magyarország]
# 1   HU  Magyarország    [Budapest, Népfürdő u. 36., 1138, Magyarország]
# 2   HU  Magyarország        [Budaörs, Hársfa u. 6., 2040, Magyarország]
# 3   HU  Magyarország  [Budapest, Egressy út 178/f., 1141, Magyarország]
# 4   HU  Magyarország      [Budapest, 1142 Budapest, 1142, Magyarország]
# 5   HU  Magyarország                                     [Magyarország]
# 6   HU  Magyarország  [Budapest, Rozgonyi Piroska u., 1031, Magyaror...
# 7   HU  Magyarország  [Budapest, Királyok útja 272. (Pünkösdfürdői ú...
# 8   HU  Magyarország                                     [Magyarország]
# 9   HU  Magyarország                                     [Magyarország]
# 10  HU  Magyarország                          [Üdülő Sor, Magyarország]
# 11  HU  Magyarország  [Budapest XXI. kerülete, Hollandi út 14., 1213...
# 12  HU  Magyarország  [Budapest, Vízisport utca 2., 1203, Magyarország]
# 13  HU  Magyarország  [Budapest, Pusztakúti út 2-6. (Fürdő utca), 10...
# 14  HU  Magyarország     [Budapest, Újhegyi út 13., 1110, Magyarország]
#
#    postalCode                    city       state              address  \
# 0        1138                Budapest    Budapest         Margitsziget
# 1        1138                Budapest    Budapest      Népfürdő u. 36.
# 2        2040                 Budaörs  Pest megye         Hársfa u. 6.
# 3        1141                Budapest    Budapest    Egressy út 178/f.
# 4        1142                Budapest    Budapest        1142 Budapest
# 5         NaN                     NaN         NaN                  NaN
# 6        1031                Budapest    Budapest  Rozgonyi Piroska u.
# 7        1039                Budapest    Budapest   Királyok útja 272.
# 8         NaN                     NaN         NaN                  NaN
# 9         NaN                     NaN         NaN                  NaN
# 10        NaN                     NaN         NaN            Üdülő Sor
# 11       1213  Budapest XXI. kerülete    Budapest      Hollandi út 14.
# 12       1203                Budapest    Budapest    Vízisport utca 2.
# 13       1038                Budapest    Budapest   Pusztakúti út 2-6.
# 14       1110                Budapest    Budapest       Újhegyi út 13.
#
#          crossStreet neighborhood                        id
# 0                NaN          NaN  4bd2fdf8caff952130bcd3f0
# 1                NaN          NaN  4c0e6d8098102d7f989ce306
# 2                NaN          NaN  4cc4ba8abde8f04d7440ad4b
# 3                NaN          NaN  4c3c367586ce328f2069ab2d
# 4                NaN          NaN  4dea07b7d22da22d4ec82ef0
# 5                NaN          NaN  51ea7a70498ea0aa94e54bd6
# 6                NaN          NaN  4c2f62663896e21ea1c9e390
# 7   Pünkösdfürdői út          NaN  4c3f41fd3735be9abb1b15a4
# 8                NaN          NaN  4ff811ebe4b0ae40ed63d1d8
# 9                NaN          NaN  4f9d7a0fe4b0e5be40828f2e
# 10               NaN          NaN  4fae719de4b04792c36c16b7
# 11               NaN          NaN  4c4ac829d2bf76b0cfa7b184
# 12               NaN          NaN  5c2717110d8a0f002c27afd4
# 13        Fürdő utca          NaN  4cc82453a32bb1f7d25aaca8
# 14               NaN          NaN  4caaadc3f47ea143d2498521

# %% [markdown]
# We see that the 6 missing baths are in this table. We select them and build a new table:

# %%
DataPool = DataPoolTemp.iloc[[0,3,6,7,12,13],:]
DataPool
# Out:
#                                              name  categories        lat  \
# 0                           Palatinus Strandfürdő  Water Park  47.529170
# 3                    Paskál Gyógy- és Strandfürdő  Water Park  47.520571
# 6                               Római Strandfürdő        Pool  47.574811
# 7                            Pünkösdfürdői Strand        Pool  47.594627
# 12  Pesterzsébeti Jódos-Sós Gyógy- És Strandfürdő        Pool  47.435448
# 13             Csillaghegyi Strandfürdő és Uszoda        Pool  47.585979
#
#           lng                                     labeledLatLngs  distance  \
# 0   19.046946  [{'label': 'display', 'lat': 47.52916959486753...      3461
# 3   19.127469  [{'label': 'display', 'lat': 47.52057142517493...      6992
# 6   19.052087  [{'label': 'display', 'lat': 47.57481146475501...      8552
# 7   19.067900  [{'label': 'display', 'lat': 47.59462716397096...     10910
# 12  19.090965  [{'label': 'display', 'lat': 47.435448, 'lng':...      7969
# 13  19.042334  [{'label': 'display', 'lat': 47.58597927264667...      9752
#
#     cc       country                                   formattedAddress  \
# 0   HU  Magyarország       [Budapest, Margitsziget, 1138, Magyarország]
# 3   HU  Magyarország  [Budapest, Egressy út 178/f., 1141, Magyarország]
# 6   HU  Magyarország  [Budapest, Rozgonyi Piroska u., 1031, Magyaror...
# 7   HU  Magyarország  [Budapest, Királyok útja 272. (Pünkösdfürdői ú...
# 12  HU  Magyarország  [Budapest, Vízisport utca 2., 1203, Magyarország]
# 13  HU  Magyarország  [Budapest, Pusztakúti út 2-6. (Fürdő utca), 10...
#
#    postalCode      city     state              address       crossStreet  \
# 0        1138  Budapest  Budapest         Margitsziget               NaN
# 3        1141  Budapest  Budapest    Egressy út 178/f.               NaN
# 6        1031  Budapest  Budapest  Rozgonyi Piroska u.               NaN
# 7        1039  Budapest  Budapest   Királyok útja 272.  Pünkösdfürdői út
# 12       1203  Budapest  Budapest    Vízisport utca 2.               NaN
# 13       1038  Budapest  Budapest   Pusztakúti út 2-6.        Fürdő utca
#
#    neighborhood                        id
# 0           NaN  4bd2fdf8caff952130bcd3f0
# 3           NaN  4c3c367586ce328f2069ab2d
# 6           NaN  4c2f62663896e21ea1c9e390
# 7           NaN  4c3f41fd3735be9abb1b15a4
# 12          NaN  5c2717110d8a0f002c27afd4
# 13          NaN  4cc82453a32bb1f7d25aaca8

# %% [markdown]
# **We can now build a dataset with the 12 offical Budapest baths**

# %%
WaterPoints = DataSpa.append(DataPool)
WaterPoints.reset_index(drop=True, inplace=True)
WaterPoints
# Out:
#                                              name  categories  \
# 0                      Rudas Gyógyfürdő és Uszoda         Spa
# 1              Szent Gellért Gyógyfürdő és Uszoda         Spa
# 2               Szent Lukács Gyógyfürdő és Uszoda         Spa
# 3                               Dandár Gyógyfürdő         Spa
# 4                  Széchenyi Gyógyfürdő és Uszoda         Spa
# 5                               Király Gyógyfürdő         Spa
# 6                           Palatinus Strandfürdő  Water Park
# 7                    Paskál Gyógy- és Strandfürdő  Water Park
# 8                               Római Strandfürdő        Pool
# 9                            Pünkösdfürdői Strand        Pool
# 10  Pesterzsébeti Jódos-Sós Gyógy- És Strandfürdő        Pool
# 11             Csillaghegyi Strandfürdő és Uszoda        Pool
#
#                    address         crossStreet        lat        lng  \
# 0         Döbrentei tér 9.  Szent Gellért rkp.  47.489188  19.047761
# 1         Kelenhegyi út 4.                 NaN  47.483917  19.052256
# 2    Frankel Leó u. 25-29.                 NaN  47.518829  19.081770
# 3             Dandár u. 3.                 NaN  47.476337  19.071061
# 4   Állatkerti körút 9-11.                 NaN  47.518302  19.082394
# 5                Fő u. 84.            Kacsa u.  47.510608  19.038185
# 6             Margitsziget                 NaN  47.529170  19.046946
# 7        Egressy út 178/f.                 NaN  47.520571  19.127469
# 8      Rozgonyi Piroska u.                 NaN  47.574811  19.052087
# 9       Királyok útja 272.    Pünkösdfürdői út  47.594627  19.067900
# 10       Vízisport utca 2.                 NaN  47.435448  19.090965
# 11      Pusztakúti út 2-6.          Fürdő utca  47.585979  19.042334
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 47.48918773695423...      1161       1013
# 1   [{'label': 'display', 'lat': 47.4839168757732,...      1838       1118
# 2   [{'label': 'display', 'lat': 47.518829, 'lng':...      3850       1023
# 3   [{'label': 'display', 'lat': 47.47633741284682...      3364       1095
# 4   [{'label': 'display', 'lat': 47.51830206635792...      3854       1146
# 5   [{'label': 'display', 'lat': 47.51060830660980...      1371       1027
# 6   [{'label': 'display', 'lat': 47.52916959486753...      3461       1138
# 7   [{'label': 'display', 'lat': 47.52057142517493...      6992       1141
# 8   [{'label': 'display', 'lat': 47.57481146475501...      8552       1031
# 9   [{'label': 'display', 'lat': 47.59462716397096...     10910       1039
# 10  [{'label': 'display', 'lat': 47.435448, 'lng':...      7969       1203
# 11  [{'label': 'display', 'lat': 47.58597927264667...      9752       1038
#
#     cc      city     state       country  \
# 0   HU  Budapest  Budapest  Magyarország
# 1   HU  Budapest  Budapest  Magyarország
# 2   HU  Budapest  Budapest  Magyarország
# 3   HU  Budapest  Budapest  Magyarország
# 4   HU  Budapest  Budapest  Magyarország
# 5   HU  Budapest  Budapest  Magyarország
# 6   HU  Budapest  Budapest  Magyarország
# 7   HU  Budapest  Budapest  Magyarország
# 8   HU  Budapest  Budapest  Magyarország
# 9   HU  Budapest  Budapest  Magyarország
# 10  HU  Budapest  Budapest  Magyarország
# 11  HU  Budapest  Budapest  Magyarország
#
#                                      formattedAddress neighborhood  \
# 0   [Budapest, Döbrentei tér 9. (Szent Gellért rkp...          NaN
# 1    [Budapest, Kelenhegyi út 4., 1118, Magyarország]          NaN
# 2   [Budapest, Frankel Leó u. 25-29., 1023, Magyar...          NaN
# 3        [Budapest, Dandár u. 3., 1095, Magyarország]          NaN
# 4   [Budapest, Állatkerti körút 9-11., 1146, Magya...   Városliget
# 5   [Budapest, Fő u. 84. (Kacsa u.), 1027, Magyaro...          NaN
# 6        [Budapest, Margitsziget, 1138, Magyarország]          NaN
# 7   [Budapest, Egressy út 178/f., 1141, Magyarország]          NaN
# 8   [Budapest, Rozgonyi Piroska u., 1031, Magyaror...          NaN
# 9   [Budapest, Királyok útja 272. (Pünkösdfürdői ú...          NaN
# 10  [Budapest, Vízisport utca 2., 1203, Magyarország]          NaN
# 11  [Budapest, Pusztakúti út 2-6. (Fürdő utca), 10...          NaN
#
#                           id
# 0   4b2a3b92f964a52058a624e3
# 1   4b2a3f25f964a52079a624e3
# 2   4b7ec53ef964a52012fe2fe3
# 3   4e4131aea809968085325a0f
# 4   4bb6452c2f70c9b606278530
# 5   4c756513ff1fb60c5915f6a7
# 6   4bd2fdf8caff952130bcd3f0
# 7   4c3c367586ce328f2069ab2d
# 8   4c2f62663896e21ea1c9e390
# 9   4c3f41fd3735be9abb1b15a4
# 10  5c2717110d8a0f002c27afd4
# 11  4cc82453a32bb1f7d25aaca8

# %% [markdown]
# **We visualize the location of the water points in Budapest**

# %% [markdown]
# In order for Folium to display correctly popups we need to remove special caracters from the hungarian names of the water points.

# %%
WaterPoints['name'] = WaterPoints.loc[:,'name'].apply(unidecode)

# %% [markdown]
# We can now create a map and display the baths with their labels in popups.

# %%
water_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the thermal bath and add each to the map
for lat, lng, label in zip(WaterPoints.lat, WaterPoints.lng, WaterPoints.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(water_points_map)

# show map
water_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We observe that the coordinates of Szent Lukas thermal bath are wrong. We informed Foursquare about this mistake but we need to correct it here. To do so we searched for the real coordinates in Google map as geopy did not find this address. Google map returns: 47.517898, 19.036682.

# %% [markdown]
# **We correct the coordinates of Szent Lukacs in the dataframe**

# %%
WaterPoints.at[2, 'lat'] = 47.517898
WaterPoints.at[2, 'lng'] = 19.036682

# %% [markdown]
# **We plot the map with the corrected coordinates**

# %%
water_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the thermal bath and add each to the map
for lat, lng, label in zip(WaterPoints.lat, WaterPoints.lng, WaterPoints.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define a circle of 5 pixels diameter around the marker
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(water_points_map)

# show map
water_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.1.3 Vegetarian or vegan restaurants <a name="veg"></a>

# %% [markdown]
# **We search for vegetarian or vegan restaurants using Foursquare API**

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100
search_query = [['vega'],['veget']]
catID = '4bf58dd8d48988d1d3941735'

dfVeg = pd.DataFrame(columns=['id', 'name', 'categories', 'location.address', 'location.lat', 'location.lng'])

for i in search_query:
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, catID, radius, LIMIT)
    
    print(i, '- OK')
    resultsVeg = requests.get(url).json()

    # assign relevant part of JSON to venues
    venuesVeg = resultsVeg['response']['venues']

    # tranform venues into a dataframe
    df = pd.json_normalize(venuesVeg)

    dfVeg=dfVeg.append(df[['id', 'name', 'categories','location.address', 'location.lat', 'location.lng']])
    search_query=search_query[+1:+1]

dfVeg.reset_index(drop=True, inplace=True)
# Out:
# ['vega'] - OK
# ['veget'] - OK

# %% [markdown]
# **Keep only columns that include venue name, and anything that is associated with location**

# %%
filtered_columns = ['name', 'categories'] + [col for col in dfVeg.columns if col.startswith('location.')] + ['id']
dfVeg_filtered = dfVeg.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfVeg_filtered['categories'] = dfVeg_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfVeg_filtered.columns = [column.split('.')[-1] for column in dfVeg_filtered.columns]

pd.set_option('display.max_rows', None)

# %% [markdown]
# **We extract only data with category "Vegetarian / Vegan Restaurant"**

# %%
DataVeg = dfVeg_filtered[dfVeg_filtered['categories']=='Vegetarian / Vegan Restaurant']
DataVeg.reset_index(drop=True, inplace=True)
DataVeg
# Out:
#                                            name  \
# 0                                      VegaCity
# 1   Édeni Vegán – Kézműves Vegetáriánus Étterem
# 2                          Nemsüti Vega Ételbár
# 3                                    Vegan Love
# 4                                  Vegan Garden
# 5                            Govinda Vega Sarok
# 6                                    Vegan king
# 7                                       Vegazzi
# 8                             Veganeria Bisztró
# 9                                     VegaKuckó
# 10                                     VegaRáma
# 11             Zen vegán és vegetáriánus konyha
# 12                              vegan food fest
# 13                                 Ganesha Vega
# 14                             VegaLife étterem
# 15                Madal Food - Vegan Restaurant
# 16                      Green Life Vegan Bakery
# 17                         827 Vegan Kitchen 2.
# 18                                  Grétá Vegán
# 19                         Deli's Vegán Bisztró
# 20                       Keep Calm And Go Vegan
# 21                                   Las Vegans
# 22                                  Las Vegan's
#
#                        categories                    address        lat  \
# 0   Vegetarian / Vegan Restaurant         Múzeum krt. 23-25.  47.491976
# 1   Vegetarian / Vegan Restaurant              Iskola u. 31.  47.505884
# 2   Vegetarian / Vegan Restaurant        Jászai Mari tér 4/b  47.513872
# 3   Vegetarian / Vegan Restaurant          Bartók Béla út 9.  47.482396
# 4   Vegetarian / Vegan Restaurant                 Dob u. 40.  47.499686
# 5   Vegetarian / Vegan Restaurant           Papnövelde u. 1.  47.490787
# 6   Vegetarian / Vegan Restaurant                        NaN  47.489668
# 7   Vegetarian / Vegan Restaurant                        33.  47.501194
# 8   Vegetarian / Vegan Restaurant            Nagymező u. 51.  47.506752
# 9   Vegetarian / Vegan Restaurant              Boraros Ter 3  47.481136
# 10  Vegetarian / Vegan Restaurant  Szabolcska Mihály utca 3.  47.476133
# 11  Vegetarian / Vegan Restaurant                        NaN  47.488925
# 12  Vegetarian / Vegan Restaurant                        NaN  47.512537
# 13  Vegetarian / Vegan Restaurant        Lágymányosi Utca 17  47.477510
# 14  Vegetarian / Vegan Restaurant               Lukács u. 1.  47.525104
# 15  Vegetarian / Vegan Restaurant            Alkotmány u. 4.  47.507331
# 16  Vegetarian / Vegan Restaurant               Lövőház Utca  47.508634
# 17  Vegetarian / Vegan Restaurant                        NaN  47.489105
# 18  Vegetarian / Vegan Restaurant                        NaN  47.490601
# 19  Vegetarian / Vegan Restaurant  Szabolcska Mihály utca 3.  47.475801
# 20  Vegetarian / Vegan Restaurant                         67  47.496265
# 21  Vegetarian / Vegan Restaurant                        NaN  47.476016
# 22  Vegetarian / Vegan Restaurant                        NaN  47.497118
#
#           lng                        id
# 0   19.061325  53c686fe498eccdf095ff308
# 1   19.037015  4bc9c8e0cc8cd13af71dbccf
# 2   19.048410  4c45356fdcd61b8d8d797c56
# 3   19.052456  56fe47ad498e04a4568bec96
# 4   19.062519  5af2bf71f00a70002c55e720
# 5   19.056462  4bd56ee75631c9b65506a430
# 6   19.055639  5cba006206fb600039dd4a4c
# 7   19.059412  5d8774986c23c0000725990a
# 8   19.055643  5abd202d0e5da853478d75d9
# 9   19.066939  59392a422bf9a934a4a386c3
# 10  19.045657  555b05cf498e6e905b45d0ef
# 11  19.060994  550b336a498eb9b173886975
# 12  19.058982  5af6c01512f0a9002c485d41
# 13  19.052621  5654454f498e779f37c4dfbb
# 14  19.039193  533c0633498e40cdada45227
# 15  19.049167  58ea04cf54073d7d2dc35194
# 16  19.026008  5e593f234a639300078cde48
# 17  19.061041  5b02c7d567a9fe002cd42ec6
# 18  19.068232  5409a13b498ed70c35f55e56
# 19  19.045647  59bbcde672475026b92e13f7
# 20  19.069632  5aba1cea3fcee8078d1af73a
# 21  19.048882  595b6f9959fe5c1d1e388d30
# 22  19.062899  58518f6d06f1a34cb4a42406

# %% [markdown]
# Twenty-three vegetarian or vegan restaurants are found in Budapest.

# %% [markdown]
# **We visualize the location of the vegetarian and vegan restaurants in Budapest**

# %% [markdown]
# In order for Folium to display correctly popups we need to remove special caracters from the hungarian names.

# %%
DataVeg['name'] = DataVeg.loc[:,'name'].apply(unidecode)
# Out:
# C:\Users\Antony\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We can now create a map and display the vegetarian and vegan restaurants with their labels in popups.

# %%
veg_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the vegetarian/vegan restaurants and add each to the map
for lat, lng, label in zip(DataVeg.lat, DataVeg.lng, DataVeg.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define a circle of 5 pixels diameter around the marker
        color='yellow',
        fill=True,
        popup=folium.Popup(label, parse_html=True),
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(veg_points_map)  

# show map
veg_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.1.4 Hungarian food restaurants <a name="hungarian"></a>

# %% [markdown]
# **We search for Hungarian food restaurants using Foursquare API**

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100
search_query = [['restaurant'], ['Vendéglő'], ['Étterem']]
catID = '52e81612bcbc57f1066b79fa'

dfHun = pd.DataFrame(columns=['id', 'name', 'categories', 'location.address', 'location.lat', 'location.lng'])

for i in search_query:
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, catID, radius, LIMIT)
    
    print(i, '- OK')
    resultsHun = requests.get(url).json()

    # assign relevant part of JSON to venues
    venuesHun = resultsHun['response']['venues']

    # tranform venues into a dataframe
    df = pd.json_normalize(venuesHun)

    dfHun=dfHun.append(df[['id', 'name', 'categories','location.address', 'location.lat', 'location.lng']])
    search_query=search_query[+1:+1]

dfHun.reset_index(drop=True, inplace=True)
# Out:
# ['restaurant'] - OK
# ['Vendéglő'] - OK
# ['Étterem'] - OK

# %% [markdown]
# **Keep only columns that include venue name, and anything that is associated with location**

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dfHun.columns if col.startswith('location.')] + ['id']
dfHun_filtered = dfHun.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfHun_filtered['categories'] = dfHun_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfHun_filtered.columns = [column.split('.')[-1] for column in dfHun_filtered.columns]

pd.set_option('display.max_rows', None)

# %% [markdown]
# **We extract only data with category "Hungarian Restaurant"**

# %%
DataHun = dfHun_filtered[dfHun_filtered['categories']=='Hungarian Restaurant']
DataHun.reset_index(drop=True, inplace=True)
DataHun
# Out:
#                         name            categories  \
# 0             Andreas Bistro  Hungarian Restaurant
# 1         21 Magyar Vendéglő  Hungarian Restaurant
# 2      Horgásztanya Vendéglő  Hungarian Restaurant
# 3          Alabárdos Étterem  Hungarian Restaurant
# 4    Halászbástya Restaurant  Hungarian Restaurant
# 5             Tüköry Étterem  Hungarian Restaurant
# 6            Márkus Vendéglő  Hungarian Restaurant
# 7  Múzeum Kávéház és Étterem  Hungarian Restaurant
# 8         Zöld Kapu Vendéglő  Hungarian Restaurant
# 9             Kéhli Vendéglő  Hungarian Restaurant
#
#                                address        lat        lng  \
# 0                         Szarka u. 1.  47.488275  19.057433
# 1                     Fortuna utca 21.  47.504124  19.031075
# 2                            Fő u. 27.  47.501962  19.039235
# 3                      Országház u. 2.  47.501725  19.032720
# 4  Halászbástya - Északi Híradástorony  47.502534  19.034489
# 5                          Hold u. 15.  47.505113  19.052301
# 6                       Lövőház u. 17.  47.509562  19.025011
# 7                      Múzeum krt. 12.  47.492046  19.061596
# 8                         Szőlő u. 42.  47.537197  19.038154
# 9                         Mókus u. 22.  47.537900  19.043370
#
#                          id
# 0  4cadbd3a0e7bbfb76f785b83
# 1  4b9a4973f964a520b7a935e3
# 2  4d137531d1848cfa680fc471
# 3  4b96b40ef964a5200edf34e3
# 4  4c72c7ed4bc4236a4330cc7a
# 5  4b6ffd53f964a5207f022de3
# 6  4be55025bcef2d7f60a403e5
# 7  4e25ca49d164b6b74afe8927
# 8  4bb47c1e0cbcef3b7bff582a
# 9  4be6a354910020a1017cd414

# %% [markdown]
# Ten Hungarian restaurants are found in Budapest.

# %% [markdown]
# **We visualize the location of the Hungarian restaurants in Budapest**

# %% [markdown]
# In order for Folium to display correctly popups we need to remove special caracters from the Hungarian names.

# %%
DataHun['name'] = DataHun.loc[:,'name'].apply(unidecode)
# Out:
# C:\Users\Antony\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We can now create a map and display the Hungarian restaurants with their labels in popups.

# %%
hun_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the vegetarian/vegan restaurants and add each to the map
for lat, lng, label in zip(DataHun.lat, DataHun.lng, DataHun.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define a circle of 5 pixels diameter around the marker
        color='yellow',
        fill=True,
        popup=folium.Popup(label, parse_html=True),
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(hun_points_map)  

# show map
hun_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.1.5 Fitness centers <a name="sport"></a>

# %% [markdown]
# **We search for fitness centers using Foursquare API**

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100
search_query = 'Fitness'
categoryID = '4bf58dd8d48988d175941735'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, categoryID, radius, LIMIT)

resultsFit = requests.get(url).json()

# assign relevant part of JSON to venues
venuesFit = resultsFit['response']['venues']

# tranform venues into a dataframe
dfFit = pd.json_normalize(venuesFit)

# %% [markdown]
# **Keep only columns that include venue name, and anything that is associated with location**

# %%
filtered_columns = ['name', 'categories'] + [col for col in dfFit.columns if col.startswith('location.')] + ['id']
dfFit_filtered = dfFit.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfFit_filtered['categories'] = dfFit_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfFit_filtered.columns = [column.split('.')[-1] for column in dfFit_filtered.columns]

# %% [markdown]
# **We extract only data with category "Gym / Fitness Center"**

# %%
DataFit = dfFit_filtered[dfFit_filtered['categories']=='Gym / Fitness Center']
DataFit.reset_index(drop=True, inplace=True)
DataFit
# Out:
#                                   name            categories  \
# 0                 F&M Fitness and More  Gym / Fitness Center
# 1                        Daily Fitness  Gym / Fitness Center
# 2                Get Fit River Fitness  Gym / Fitness Center
# 3                              Fitness  Gym / Fitness Center
# 4                Nova-Sun Fitness Club  Gym / Fitness Center
# 5                        Menta Fitness  Gym / Fitness Center
# 6              nr1 fitness -Kálvin tér  Gym / Fitness Center
# 7             Universum Fitness Récsei  Gym / Fitness Center
# 8             SCITEC Gold Fitness Club  Gym / Fitness Center
# 9   Fitness and Health Club by Mariott  Gym / Fitness Center
# 10                   CathaWahl Fitness  Gym / Fitness Center
# 11             Color Millenium Fitness  Gym / Fitness Center
# 12                    New York Fitness  Gym / Fitness Center
# 13               Life1 Nyugati Fitness  Gym / Fitness Center
# 14                Arena Fitness Center  Gym / Fitness Center
# 15                 Bank Center Fitness  Gym / Fitness Center
# 16      Fitness Works powered by Life1  Gym / Fitness Center
# 17                  Fitness Five & Gym  Gym / Fitness Center
# 18                   Gilda Max Fitness  Gym / Fitness Center
# 19                   John Reed Fitness  Gym / Fitness Center
# 20                  Livingroom Fitness  Gym / Fitness Center
# 21            Green Fitness and Beauty  Gym / Fitness Center
# 22            Castrum Fitness&Wellness  Gym / Fitness Center
# 23                      Fitness Center  Gym / Fitness Center
# 24                          4% FiTNESS  Gym / Fitness Center
# 25                    MB Spa & Fitness  Gym / Fitness Center
# 26                  Goldenlife Fitness  Gym / Fitness Center
# 27                    A Fitness Újbuda  Gym / Fitness Center
#
#                              address        lat        lng  \
# 0                 Csörsz utca 14-16.  47.489801  19.022896
# 1                        Pálya u. 9.  47.495484  19.028377
# 2                      Révész u. 29.  47.527996  19.056998
# 3                   Boscolo Budapest  47.498743  19.070396
# 4                        Kádár u. 6.  47.511663  19.055173
# 5              Szent István krt. 10.  47.512604  19.050000
# 6                   Kecskeméti u. 14  47.489930  19.061149
# 7                  Istvánmezei út 6.  47.505183  19.092904
# 8                     Lurdy Ház fsz.  47.470829  19.083172
# 9                                NaN  47.494451  19.049471
# 10                     HALASZ UTCA 2  47.501760  19.039462
# 11                   Váci Utca 19-21  47.493526  19.051981
# 12                 Késmárk u. 32-34.  47.529621  19.150410
# 13                  Nyugati tér 1-2.  47.509816  19.056108
# 14  Duna Plaza Parkolóház, 5. emelet  47.551200  19.072919
# 15                  Szabadság tér 7.  47.502999  19.051942
# 16                    Föveny u. 4-6.  47.544313  19.073346
# 17                    Campona emelet  47.406283  19.015868
# 18                       Váci út 35.  47.525315  19.064796
# 19                        Váci út 45  47.527947  19.066436
# 20         II. János Pál Pápa tér 6.  47.495558  19.076886
# 21     Nagy Lajos Király útja 135/a.  47.518155  19.114575
# 22                Lechner Ödön fasor  47.476093  19.068611
# 23                  Lazar Utca 11-13  47.502363  19.056501
# 24                    Ráday utca 16.  47.487419  19.063551
# 25                               NaN  47.494768  19.049050
# 26               Arany Janos Utca 12  47.502013  19.048774
# 27             Nándorfejérvári Út 40  47.460512  19.045739
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 47.48980059796192...      1630       1123
# 1   [{'label': 'display', 'lat': 47.49548424379652...       965       1012
# 2   [{'label': 'display', 'lat': 47.52799626316895...      3523       1138
# 3   [{'label': 'display', 'lat': 47.49874304289823...      2250        NaN
# 4   [{'label': 'display', 'lat': 47.51166280485033...      1846       1132
# 5   [{'label': 'display', 'lat': 47.51260443754759...      1737       1137
# 6   [{'label': 'display', 'lat': 47.48993034830719...      1817       1053
# 7   [{'label': 'display', 'lat': 47.50518278440155...      4015       1146
# 8   [{'label': 'display', 'lat': 47.47082893042727...      4441        NaN
# 9   [{'label': 'display', 'lat': 47.4944506725873,...       806       1051
# 10  [{'label': 'display', 'lat': 47.50176, 'lng': ...       383       1011
# 11  [{'label': 'display', 'lat': 47.4935258622675,...      1020       1052
# 12  [{'label': 'display', 'lat': 47.52962115650138...      8967       1158
# 13  [{'label': 'display', 'lat': 47.50981597569512...      1732       1066
# 14  [{'label': 'display', 'lat': 47.5511995276343,...      6365       1138
# 15  [{'label': 'display', 'lat': 47.50299926787549...      1004       1054
# 16  [{'label': 'display', 'lat': 47.54431344831723...      5679       1138
# 17  [{'label': 'display', 'lat': 47.40628320002835...     10418       1222
# 18  [{'label': 'display', 'lat': 47.52531519778181...      3512       1136
# 19  [{'label': 'display', 'lat': 47.52794728896286...      3826       1134
# 20  [{'label': 'display', 'lat': 47.49555754609827...      2756        NaN
# 21  [{'label': 'display', 'lat': 47.51815506756031...      5991       1149
# 22  [{'label': 'display', 'lat': 47.47609252202446...      3261        NaN
# 23  [{'label': 'display', 'lat': 47.502363, 'lng':...      1284       1065
# 24  [{'label': 'display', 'lat': 47.48741894786818...      2121       1092
# 25  [{'label': 'display', 'lat': 47.494768, 'lng':...       760        NaN
# 26  [{'label': 'display', 'lat': 47.50201303744633...       743        NaN
# 27  [{'label': 'display', 'lat': 47.46051232597493...      4234        NaN
#
#     cc                  city               state       country  \
# 0   HU              Budapest            Budapest  Magyarország
# 1   HU              Budapest            Budapest  Magyarország
# 2   HU              Budapest            Budapest  Magyarország
# 3   HU              Budapest            Budapest  Magyarország
# 4   HU              Budapest            Budapest  Magyarország
# 5   HU              Budapest            Budapest  Magyarország
# 6   HU   Budapest V. kerület            Budapest  Magyarország
# 7   HU              Budapest            Budapest  Magyarország
# 8   HU              Budapest            Budapest  Magyarország
# 9   HU              Budapest            Budapest  Magyarország
# 10  HU              Budapest            Budapest  Magyarország
# 11  HU              Budapest            Budapest  Magyarország
# 12  HU              Budapest            Budapest  Magyarország
# 13  HU              Budapest            Budapest  Magyarország
# 14  HU              Budapest            Budapest  Magyarország
# 15  HU              Budapest            Budapest  Magyarország
# 16  HU              Budapest            Budapest  Magyarország
# 17  HU              Budapest            Budapest  Magyarország
# 18  HU              Budapest            Budapest  Magyarország
# 19  HU              Budapest  Közép-Magyarország  Magyarország
# 20  HU              Budapest            Budapest  Magyarország
# 21  HU              Budapest            Budapest  Magyarország
# 22  HU                   NaN                 NaN  Magyarország
# 23  HU  Budapest VI. kerület            Budapest  Magyarország
# 24  HU  Budapest IX. kerület            Budapest  Magyarország
# 25  HU                   NaN                 NaN  Magyarország
# 26  HU                   NaN                 NaN  Magyarország
# 27  HU              Budapest            Budapest  Magyarország
#
#                                      formattedAddress           crossStreet  \
# 0   [Budapest, Csörsz utca 14-16., 1123, Magyarors...                   NaN
# 1   [Budapest, Pálya u. 9. (Márvány u.), 1012, Mag...            Márvány u.
# 2   [Budapest, Révész u. 29. (Dráva u.), 1138, Mag...              Dráva u.
# 3   [Budapest, Boscolo Budapest (Erzsébet krt.), M...         Erzsébet krt.
# 4         [Budapest, Kádár u. 6., 1132, Magyarország]                   NaN
# 5   [Budapest, Szent István krt. 10., 1137, Magyar...                   NaN
# 6   [Budapest V. kerület, Kecskeméti u. 14 (Kalvin...            Kalvin ter
# 7   [Budapest, Istvánmezei út 6., 1146, Magyarország]                   NaN
# 8   [Budapest, Lurdy Ház fsz. (Mester utca), Magya...           Mester utca
# 9                      [Budapest, 1051, Magyarország]                   NaN
# 10      [Budapest, HALASZ UTCA 2, 1011, Magyarország]                   NaN
# 11    [Budapest, Váci Utca 19-21, 1052, Magyarország]                   NaN
# 12  [Budapest, Késmárk u. 32-34., 1158, Magyarország]                   NaN
# 13   [Budapest, Nyugati tér 1-2., 1066, Magyarország]                   NaN
# 14  [Budapest, Duna Plaza Parkolóház, 5. emelet, 1...                   NaN
# 15   [Budapest, Szabadság tér 7., 1054, Magyarország]                   NaN
# 16  [Budapest, Föveny u. 4-6. (Váci Greens irodahá...  Váci Greens irodaház
# 17     [Budapest, Campona emelet, 1222, Magyarország]                   NaN
# 18        [Budapest, Váci út 35., 1136, Magyarország]                   NaN
# 19  [Budapest, Váci út 45 (Apály u.), 1134, Magyar...              Apály u.
# 20  [Budapest, II. János Pál Pápa tér 6., Magyaror...                   NaN
# 21  [Budapest, Nagy Lajos Király útja 135/a. (Bosn...           Bosnyák tér
# 22                 [Lechner Ödön fasor, Magyarország]                   NaN
# 23  [Budapest VI. kerület, Lazar Utca 11-13, 1065,...                   NaN
# 24  [Budapest IX. kerület, Ráday utca 16., 1092, M...                   NaN
# 25                                     [Magyarország]                   NaN
# 26                [Arany Janos Utca 12, Magyarország]                   NaN
# 27    [Budapest, Nándorfejérvári Út 40, Magyarország]                   NaN
#
#             neighborhood                        id
# 0                    NaN  5221e9d9498eba5714347373
# 1         Krisztinaváros  4d235202dd6a236a62fd4e38
# 2                    NaN  54b127e8498e6f78be8fa07f
# 3                    NaN  4feb4136e4b008a767ee16cb
# 4                    NaN  4cd15a816449a093908acfcf
# 5                    NaN  4ea68715b8f7b8a60b45a323
# 6   Budapest V. kerülete  5aa65d8ed8096e450c623b2d
# 7                    NaN  5076a96fe4b0eca51a17723b
# 8                    NaN  53a85b9c498e26d9ca5e3d1f
# 9                    NaN  58dcc9a4dfa6ff04ddad35fc
# 10                   NaN  5c92bdbd3fcee8002c526054
# 11                   NaN  542a6896498e51a58da85882
# 12                   NaN  4d6928291b63a1cd0bda3b2d
# 13                   NaN  560e83d3498e4fc99abe2d09
# 14            Angyalföld  4cd438ce558a37048120c6a6
# 15                   NaN  4d407ec689616dcb0a2905b5
# 16            Angyalföld  5846a80be612f25f608614a8
# 17                   NaN  4d2dc9ddfeaaa1cd67a8eb90
# 18            Angyalföld  4bc6153d51b376b07cf41a6f
# 19                   NaN  586f9d80d4ab7350e1ccdf4d
# 20                   NaN  5383823a498ea82192dd03a0
# 21                   NaN  5241ce9d498e398e6ef4e706
# 22                   NaN  4f4beb8ce4b0705904b2e3ab
# 23                   NaN  5d1ee9ba4dcbca002f88fdb0
# 24                   NaN  5b18fd3f345cbe002c363998
# 25                   NaN  52341bb811d2eedd0fc361f2
# 26                   NaN  52f1065911d2c17a4c68d1cc
# 27                   NaN  55fd3d67498e48f495ec0cf3

# %% [markdown]
# Twenty-eight fitness centers are found in Budapest.

# %% [markdown]
# **We visualize the location of the fitness centers in Budapest**

# %% [markdown]
# In order for Folium to display correctly popups we need to remove special caracters from the hungarian names.

# %%
DataFit['name'] = DataFit.loc[:,'name'].apply(unidecode)
# Out:
# C:\Users\Antony\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We can now create a map and display the fitness centers with their labels in popups.

# %%
fit_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the thermal bath and add each to the map
for lat, lng, label in zip(DataFit.lat, DataFit.lng, DataFit.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(fit_points_map)

# show map
fit_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.1.6 Conference rooms <a name="conference"></a>

# %% [markdown]
# **We search for conference rooms using Foursquare API**

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100
search_query = 'conference'
categoryID = '4bf58dd8d48988d127941735'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, categoryID, radius, LIMIT)

resultsConf = requests.get(url).json()

# assign relevant part of JSON to venues
venuesConf = resultsConf['response']['venues']

# tranform venues into a dataframe
dfConf = pd.json_normalize(venuesConf)

# %% [markdown]
# **Keep only columns that include venue name, and anything that is associated with location**

# %%
filtered_columns = ['name', 'categories'] + [col for col in dfConf.columns if col.startswith('location.')] + ['id']
dfConf_filtered = dfConf.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfConf_filtered['categories'] = dfConf_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfConf_filtered.columns = [column.split('.')[-1] for column in dfConf_filtered.columns]

# %% [markdown]
# **We extract only data with category "Conference Room"**

# %%
DataConf = dfConf_filtered[dfConf_filtered['categories']=='Conference Room']
DataConf.reset_index(drop=True, inplace=True)
DataConf
# Out:
#                                     name       categories        lat  \
# 0                 Quince Conference Room  Conference Room  47.492252
# 1                  CEU Conference Centre  Conference Room  47.505467
# 2              Avaya conference room 501  Conference Room  47.514064
# 3               Boscolo Conference Rooms  Conference Room  47.498739
# 4            Ibis Styles Conference Room  Conference Room  47.479287
# 5          Conference Room 1. Emelet 150  Conference Room  47.456741
# 6                  REC Conference Centre  Conference Room  47.491492
# 7      Lm Ericsson Hilda Conference Area  Conference Room  47.470818
# 8   AB InBev, Samlesbury Conference Room  Conference Room  47.533220
# 9           Chello Sport Conference Room  Conference Room  47.537034
# 10               Ustream Conference Room  Conference Room  47.562093
#
#           lng                                     labeledLatLngs  distance  \
# 0   19.050831  [{'label': 'display', 'lat': 47.492252, 'lng':...      1035
# 1   19.159598  [{'label': 'display', 'lat': 47.50546709343197...      8993
# 2   19.058598  [{'label': 'display', 'lat': 47.514064, 'lng':...      2214
# 3   19.070873  [{'label': 'display', 'lat': 47.498739, 'lng':...      2286
# 4   19.068935  [{'label': 'display', 'lat': 47.479287, 'lng':...      3017
# 5   18.935946  [{'label': 'display', 'lat': 47.45674133300781...      9128
# 6   19.081253  [{'label': 'display', 'lat': 47.49149166428705...      3161
# 7   19.062943  [{'label': 'display', 'lat': 47.470818, 'lng':...      3503
# 8   19.059249  [{'label': 'display', 'lat': 47.53322044813539...      4127
# 9   19.070936  [{'label': 'display', 'lat': 47.537034, 'lng':...      4874
# 10  19.055568  [{'label': 'display', 'lat': 47.56209339546706...      7182
#
#     cc       country                                   formattedAddress  \
# 0   HU  Magyarország  [Budapest, Marcius 15. ter 1 4. emelet, 1056, ...
# 1   HU  Magyarország  [Budapest, Kerepesi út 87. (Pogány utca), 1106...
# 2   HU  Magyarország                                     [Magyarország]
# 3   HU  Magyarország        [Budapest VII. kerület, 1073, Magyarország]
# 4   HU  Magyarország         [Budapest IX. kerület, 1095, Magyarország]
# 5   HU  Magyarország                                     [Magyarország]
# 6   HU  Magyarország                                     [Magyarország]
# 7   HU  Magyarország                     [Budapest, 1117, Magyarország]
# 8   HU  Magyarország                   [Népfürdõ Utca 22, Magyarország]
# 9   HU  Magyarország                                     [Magyarország]
# 10  HU  Magyarország                           [Budapest, Magyarország]
#
#                         address postalCode                   city     state  \
# 0   Marcius 15. ter 1 4. emelet       1056               Budapest  Budapest
# 1               Kerepesi út 87.       1106               Budapest  Budapest
# 2                           NaN        NaN                    NaN       NaN
# 3                           NaN       1073  Budapest VII. kerület  Budapest
# 4                           NaN       1095   Budapest IX. kerület  Budapest
# 5                           NaN        NaN                    NaN       NaN
# 6                           NaN        NaN                    NaN       NaN
# 7                           NaN       1117               Budapest  Budapest
# 8              Népfürdõ Utca 22        NaN                    NaN       NaN
# 9                           NaN        NaN                    NaN       NaN
# 10                          NaN        NaN               Budapest  Budapest
#
#     crossStreet neighborhood                        id
# 0           NaN          NaN  4cdd4c5622bd721e0a330048
# 1   Pogány utca          NaN  4bd70cc3304fce72ef1633ab
# 2           NaN          NaN  507d2223e4b03d34a5c2d5fe
# 3           NaN          NaN  59bb9c82a0215b132c7e12ff
# 4           NaN          NaN  595e27d6f427de4acf7eed2a
# 5           NaN          NaN  50a24821e4b0e8ebc19bfcf5
# 6           NaN          NaN  4f93c84de4b08038d81ce63b
# 7           NaN   Lágymányos  5b07ee774420d8002ca75bb5
# 8           NaN          NaN  50893de4e4b0b52a6b4574a3
# 9           NaN          NaN  5375f93c498eacae73301125
# 10          NaN          NaN  4e149775fa7622d439eb9f92

# %% [markdown]
# Eleven conference rooms are found in Budapest.

# %% [markdown]
# **We visualize the location of the conference rooms in Budapest**

# %% [markdown]
# In order for Folium to display correctly popups we need to remove special caracters from the hungarian names.

# %%
DataConf['name'] = DataConf.loc[:,'name'].apply(unidecode)
# Out:
# C:\Users\Antony\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We can now create a map and display the conference rooms with their labels in popups.

# %%
conf_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the thermal bath and add each to the map
for lat, lng, label in zip(DataConf.lat, DataConf.lng, DataConf.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(conf_points_map)

# show map
conf_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.1.7 Libraries <a name="libraries"></a>

# %% [markdown]
# **We search for libraries using Foursquare API**

# %%
VERSION = '20180605' # Foursquare API version
radius = 12000 #in meters
LIMIT = 100
search_query = 'library' #means thermal bath in Hungarian
categoryID = '4bf58dd8d48988d12f941735'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&categoryID={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latBUD, longBUD, VERSION, search_query, categoryID, radius, LIMIT)

resultsLib = requests.get(url).json()

# assign relevant part of JSON to venues
venuesLib = resultsLib['response']['venues']

# tranform venues into a dataframe
dfLib = pd.json_normalize(venuesLib)

# %% [markdown]
# **Keep only columns that include venue name, and anything that is associated with location**

# %%
filtered_columns = ['name', 'categories'] + [col for col in dfLib.columns if col.startswith('location.')] + ['id']
dfLib_filtered = dfLib.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfLib_filtered['categories'] = dfLib_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfLib_filtered.columns = [column.split('.')[-1] for column in dfLib_filtered.columns]

# %% [markdown]
# **We extract only data with category "Library" or "College Library"**

# %%
DataLib = dfLib_filtered[dfLib_filtered['categories'].isin(['Library', 'College Library']) ]
DataLib.reset_index(drop=True, inplace=True)
DataLib
# Out:
#                                                  name       categories  \
# 0   ELTE Egyetemi Könyvtár és Levéltár / ELTE Univ...  College Library
# 1                 Central European University Library  College Library
# 2                                         CEU Library  College Library
# 3                                      Street Library          Library
# 4     SEAS Library (Angol-amerikai Intézet könyvtára)  College Library
# 5                     CEU Library of Medieval Studies  College Library
# 6                          Budapest Christian Library          Library
# 7                                         IBS Library  College Library
# 8   Semmelweis Orvostörténeti Könyvtár / Semmelwei...          Library
# 9                                         HIK Library  College Library
# 10         Semmelweis University Central Library 7/24  College Library
# 11                     Országos Idegennyelvű Könyvtár          Library
# 12  Óbudai Egyetem - "Building - D" - Könyvtár - L...  College Library
# 13                                        IBS Library  College Library
# 14               Semmelweis Egyetem Központi Könyvtár  College Library
# 15                                  Spiritual Library  College Library
# 16         Hutÿra Ferenc Könyvtár, Levéltár és Múzeum  College Library
# 17            Gr. Bercsényi Zsuzsanna Városi Könyvtár  College Library
# 18                                       Aisb Library          Library
#
#                     address        lat        lng  \
# 0         Ferenciek tere 6.  47.492537  19.057242
# 1             Nádor utca 15  47.501188  19.049612
# 2               Nádor u 15.  47.501186  19.049579
# 3                       NaN  47.497900  19.054249
# 4                  ELTE BTK  47.492876  19.061628
# 5   Múzeum krt. 6-8. I. em.  47.492969  19.061665
# 6       Szent Gellért tér 3  47.483071  19.053922
# 7                       NaN  47.500655  19.067055
# 8            Török utca 12.  47.516056  19.036453
# 9            Reviczky u. 4.  47.489717  19.065528
# 10      Mikszáth Kálmán tér  47.489231  19.065426
# 11            Molnár u. 11.  47.490290  19.053709
# 12                      NaN  47.533168  19.033647
# 13                      NaN  47.520944  18.990944
# 14   Mikszáth Kálmán tér 5.  47.489871  19.066621
# 15           Baradla Street  47.476457  18.991289
# 16             István u. 2.  47.503402  19.076336
# 17      Károly király u. 20  47.458923  18.958576
# 18                      NaN  47.569683  18.899683
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 47.49253702166014...      1419       1053
# 1   [{'label': 'display', 'lat': 47.50118807096102...       755       1051
# 2   [{'label': 'display', 'lat': 47.50118556542106...       752       1051
# 3   [{'label': 'display', 'lat': 47.4979, 'lng': 1...      1037        NaN
# 4   [{'label': 'display', 'lat': 47.49287573389571...      1705        NaN
# 5   [{'label': 'display', 'lat': 47.49296923102233...      1704        NaN
# 6   [{'label': 'display', 'lat': 47.48307118997125...      1982        NaN
# 7   [{'label': 'display', 'lat': 47.50065465575044...      2015        NaN
# 8   [{'label': 'display', 'lat': 47.51605582974233...      1990       1023
# 9   [{'label': 'display', 'lat': 47.48971696889715...      2117        NaN
# 10  [{'label': 'display', 'lat': 47.489231, 'lng':...      2135       1088
# 11  [{'label': 'display', 'lat': 47.49028969993495...      1342       1056
# 12  [{'label': 'display', 'lat': 47.53316804840164...      3906        NaN
# 13  [{'label': 'display', 'lat': 47.520944, 'lng':...      4491        NaN
# 14  [{'label': 'display', 'lat': 47.48987133815054...      2183       1088
# 15  [{'label': 'display', 'lat': 47.47645650851555...      4432       1112
# 16  [{'label': 'display', 'lat': 47.50340222387283...      2754       1078
# 17  [{'label': 'display', 'lat': 47.45892250440868...      7566       2040
# 18  [{'label': 'display', 'lat': 47.569683, 'lng':...     13227       2094
#
#     cc                    city            state       country  \
# 0   HU                Budapest         Budapest  Magyarország
# 1   HU                Budapest         Budapest  Magyarország
# 2   HU                Budapest         Budapest  Magyarország
# 3   HU                     NaN              NaN  Magyarország
# 4   HU                Budapest         Budapest  Magyarország
# 5   HU                Budapest         Budapest  Magyarország
# 6   HU                Budapest         Budapest  Magyarország
# 7   HU                     NaN              NaN  Magyarország
# 8   HU                Budapest         Budapest  Magyarország
# 9   HU                Budapest         Budapest  Magyarország
# 10  HU  Budapest VIII. kerület        Budapeşte  Magyarország
# 11  HU                Budapest         Budapest  Magyarország
# 12  HU                     NaN              NaN  Magyarország
# 13  HU                Budapest         Budapest  Magyarország
# 14  HU                Budapest              NaN  Magyarország
# 15  HU                Budapest         Budapest  Magyarország
# 16  HU                Budapest         Budapest  Magyarország
# 17  HU                 Budaörs       Pest megye  Magyarország
# 18  HU             Nagykovácsi  Comitat de Pest  Magyarország
#
#                                      formattedAddress      crossStreet  \
# 0   [Budapest, Ferenciek tere 6., 1053, Magyarország]              NaN
# 1   [Budapest, Nádor utca 15 (Zrínyi utca), 1051, ...      Zrínyi utca
# 2         [Budapest, Nádor u 15., 1051, Magyarország]              NaN
# 3                                      [Magyarország]              NaN
# 4                  [Budapest, ELTE BTK, Magyarország]              NaN
# 5   [Budapest, Múzeum krt. 6-8. I. em., Magyarország]              NaN
# 6       [Budapest, Szent Gellért tér 3, Magyarország]              NaN
# 7                                      [Magyarország]              NaN
# 8   [Budapest, Török utca 12. (Gül Baba utca), 102...    Gül Baba utca
# 9   [Budapest, Reviczky u. 4. (Szentkirályi u.), M...  Szentkirályi u.
# 10  [Budapest VIII. kerület, Mikszáth Kálmán tér, ...              NaN
# 11      [Budapest, Molnár u. 11., 1056, Magyarország]              NaN
# 12                                     [Magyarország]              NaN
# 13                           [Budapest, Magyarország]              NaN
# 14  [Budapest, Mikszáth Kálmán tér 5., 1088, Magya...              NaN
# 15     [Budapest, Baradla Street, 1112, Magyarország]              NaN
# 16  [Budapest, István u. 2. (Rottenbiller u.), 107...  Rottenbiller u.
# 17  [Budaörs, Károly király u. 20, 2040, Magyarors...              NaN
# 18                  [Nagykovácsi, 2094, Magyarország]              NaN
#
#               neighborhood                        id
# 0                      NaN  4d4b580f2220b1f7e69a29d2
# 1               Lipótváros  4d8793ce5ad3a093ec880efe
# 2                      NaN  4d8792bb40a7a35d95d14abe
# 3                      NaN  5181575c498ea211c248c6dc
# 4   Budapest VII. kerülete  506376f2e4b07031a91ddce7
# 5                      NaN  4ecb82868b813b34fe278ad5
# 6                      NaN  4dcaab36e4cde9e42f8b8289
# 7                      NaN  51656cbde4b073f745c96050
# 8                      NaN  524d394dbce6d140699720f0
# 9                      NaN  4c1cbe018b3aa593f54c995f
# 10                     NaN  592f3fb467a9fe69dcbf9ee1
# 11                     NaN  4e89c13e0aaf6ba4a373fed6
# 12                     NaN  50222bb5e4b04afbc67bf73b
# 13                     NaN  5370a2aa498e14346f19061e
# 14                     NaN  4c27034ff1272d7f24a087c5
# 15                     NaN  50f09a38e4b0f39bc38cafb1
# 16                     NaN  4dc941b0d4c0b6a6a7fa0c72
# 17                     NaN  4cd4211672a1a1cdedf96851
# 18                     NaN  59f84afa6bd36b45878a14e1

# %% [markdown]
# Nineteen libraries are found in Budapest.

# %% [markdown]
# **We visualize the location of the libraries in Budapest**

# %% [markdown]
# In order for Folium to display correctly popups we need to remove special caracters from the hungarian names.

# %%
DataLib['name'] = DataLib.loc[:,'name'].apply(unidecode)
# Out:
# C:\Users\Antony\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We can now create a map and display the libraries with their labels in popups.

# %%
lib_points_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# loop through the thermal bath and add each to the map
for lat, lng, label in zip(DataLib.lat, DataLib.lng, DataLib.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(lib_points_map)

# show map
lib_points_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 2.1.8 Concatenate venues datasets <a name="venuesdata"></a>

# %% [markdown]
# We have gathered all the geospatial and associated data we needed from Foursquare. We can now concatenate the 6 datasets containing the different venues of interest.

# %% [markdown]
# **Concatenate all dataframes containing the data about thermal bath and spa, vegetarian and vegan restaurants, Hungarian food restaurant, fitness centers, conference rooms and libraries.**

# %%
DataFull = pd.concat([WaterPoints, DataVeg, DataHun, DataFit, DataConf, DataLib], ignore_index=True)
DataFull.iloc[:,[0,1,4,5]]
# Out:
#                                                   name  \
# 0                           Rudas Gyogyfurdo es Uszoda
# 1                   Szent Gellert Gyogyfurdo es Uszoda
# 2                    Szent Lukacs Gyogyfurdo es Uszoda
# 3                                    Dandar Gyogyfurdo
# 4                       Szechenyi Gyogyfurdo es Uszoda
# 5                                    Kiraly Gyogyfurdo
# 6                                Palatinus Strandfurdo
# 7                         Paskal Gyogy- es Strandfurdo
# 8                                    Romai Strandfurdo
# 9                                 Punkosdfurdoi Strand
# 10       Pesterzsebeti Jodos-Sos Gyogy- Es Strandfurdo
# 11                  Csillaghegyi Strandfurdo es Uszoda
# 12                                            VegaCity
# 13         Edeni Vegan - Kezmuves Vegetarianus Etterem
# 14                                Nemsuti Vega Etelbar
# 15                                          Vegan Love
# 16                                        Vegan Garden
# 17                                  Govinda Vega Sarok
# 18                                          Vegan king
# 19                                             Vegazzi
# 20                                   Veganeria Bisztro
# 21                                           VegaKucko
# 22                                            VegaRama
# 23                    Zen vegan es vegetarianus konyha
# 24                                     vegan food fest
# 25                                        Ganesha Vega
# 26                                    VegaLife etterem
# 27                       Madal Food - Vegan Restaurant
# 28                             Green Life Vegan Bakery
# 29                                827 Vegan Kitchen 2.
# 30                                         Greta Vegan
# 31                                Deli's Vegan Bisztro
# 32                              Keep Calm And Go Vegan
# 33                                          Las Vegans
# 34                                         Las Vegan's
# 35                                      Andreas Bistro
# 36                                  21 Magyar Vendeglo
# 37                               Horgasztanya Vendeglo
# 38                                   Alabardos Etterem
# 39                             Halaszbastya Restaurant
# 40                                      Tukory Etterem
# 41                                     Markus Vendeglo
# 42                           Muzeum Kavehaz es Etterem
# 43                                  Zold Kapu Vendeglo
# 44                                      Kehli Vendeglo
# 45                                F&M Fitness and More
# 46                                       Daily Fitness
# 47                               Get Fit River Fitness
# 48                                             Fitness
# 49                               Nova-Sun Fitness Club
# 50                                       Menta Fitness
# 51                             nr1 fitness -Kalvin ter
# 52                            Universum Fitness Recsei
# 53                            SCITEC Gold Fitness Club
# 54                  Fitness and Health Club by Mariott
# 55                                   CathaWahl Fitness
# 56                             Color Millenium Fitness
# 57                                    New York Fitness
# 58                               Life1 Nyugati Fitness
# 59                                Arena Fitness Center
# 60                                 Bank Center Fitness
# 61                      Fitness Works powered by Life1
# 62                                  Fitness Five & Gym
# 63                                   Gilda Max Fitness
# 64                                   John Reed Fitness
# 65                                  Livingroom Fitness
# 66                            Green Fitness and Beauty
# 67                            Castrum Fitness&Wellness
# 68                                      Fitness Center
# 69                                          4% FiTNESS
# 70                                    MB Spa & Fitness
# 71                                  Goldenlife Fitness
# 72                                    A Fitness Ujbuda
# 73                              Quince Conference Room
# 74                               CEU Conference Centre
# 75                           Avaya conference room 501
# 76                            Boscolo Conference Rooms
# 77                         Ibis Styles Conference Room
# 78                       Conference Room 1. Emelet 150
# 79                               REC Conference Centre
# 80                   Lm Ericsson Hilda Conference Area
# 81                AB InBev, Samlesbury Conference Room
# 82                        Chello Sport Conference Room
# 83                             Ustream Conference Room
# 84   ELTE Egyetemi Konyvtar es Leveltar / ELTE Univ...
# 85                 Central European University Library
# 86                                         CEU Library
# 87                                      Street Library
# 88     SEAS Library (Angol-amerikai Intezet konyvtara)
# 89                     CEU Library of Medieval Studies
# 90                          Budapest Christian Library
# 91                                         IBS Library
# 92   Semmelweis Orvostorteneti Konyvtar / Semmelwei...
# 93                                         HIK Library
# 94          Semmelweis University Central Library 7/24
# 95                      Orszagos Idegennyelvu Konyvtar
# 96   Obudai Egyetem - "Building - D" - Konyvtar - L...
# 97                                         IBS Library
# 98                Semmelweis Egyetem Kozponti Konyvtar
# 99                                   Spiritual Library
# 100         Hutyra Ferenc Konyvtar, Leveltar es Muzeum
# 101            Gr. Bercsenyi Zsuzsanna Varosi Konyvtar
# 102                                       Aisb Library
#
#                         categories        lat        lng
# 0                              Spa  47.489188  19.047761
# 1                              Spa  47.483917  19.052256
# 2                              Spa  47.517898  19.036682
# 3                              Spa  47.476337  19.071061
# 4                              Spa  47.518302  19.082394
# 5                              Spa  47.510608  19.038185
# 6                       Water Park  47.529170  19.046946
# 7                       Water Park  47.520571  19.127469
# 8                             Pool  47.574811  19.052087
# 9                             Pool  47.594627  19.067900
# 10                            Pool  47.435448  19.090965
# 11                            Pool  47.585979  19.042334
# 12   Vegetarian / Vegan Restaurant  47.491976  19.061325
# 13   Vegetarian / Vegan Restaurant  47.505884  19.037015
# 14   Vegetarian / Vegan Restaurant  47.513872  19.048410
# 15   Vegetarian / Vegan Restaurant  47.482396  19.052456
# 16   Vegetarian / Vegan Restaurant  47.499686  19.062519
# 17   Vegetarian / Vegan Restaurant  47.490787  19.056462
# 18   Vegetarian / Vegan Restaurant  47.489668  19.055639
# 19   Vegetarian / Vegan Restaurant  47.501194  19.059412
# 20   Vegetarian / Vegan Restaurant  47.506752  19.055643
# 21   Vegetarian / Vegan Restaurant  47.481136  19.066939
# 22   Vegetarian / Vegan Restaurant  47.476133  19.045657
# 23   Vegetarian / Vegan Restaurant  47.488925  19.060994
# 24   Vegetarian / Vegan Restaurant  47.512537  19.058982
# 25   Vegetarian / Vegan Restaurant  47.477510  19.052621
# 26   Vegetarian / Vegan Restaurant  47.525104  19.039193
# 27   Vegetarian / Vegan Restaurant  47.507331  19.049167
# 28   Vegetarian / Vegan Restaurant  47.508634  19.026008
# 29   Vegetarian / Vegan Restaurant  47.489105  19.061041
# 30   Vegetarian / Vegan Restaurant  47.490601  19.068232
# 31   Vegetarian / Vegan Restaurant  47.475801  19.045647
# 32   Vegetarian / Vegan Restaurant  47.496265  19.069632
# 33   Vegetarian / Vegan Restaurant  47.476016  19.048882
# 34   Vegetarian / Vegan Restaurant  47.497118  19.062899
# 35            Hungarian Restaurant  47.488275  19.057433
# 36            Hungarian Restaurant  47.504124  19.031075
# 37            Hungarian Restaurant  47.501962  19.039235
# 38            Hungarian Restaurant  47.501725  19.032720
# 39            Hungarian Restaurant  47.502534  19.034489
# 40            Hungarian Restaurant  47.505113  19.052301
# 41            Hungarian Restaurant  47.509562  19.025011
# 42            Hungarian Restaurant  47.492046  19.061596
# 43            Hungarian Restaurant  47.537197  19.038154
# 44            Hungarian Restaurant  47.537900  19.043370
# 45            Gym / Fitness Center  47.489801  19.022896
# 46            Gym / Fitness Center  47.495484  19.028377
# 47            Gym / Fitness Center  47.527996  19.056998
# 48            Gym / Fitness Center  47.498743  19.070396
# 49            Gym / Fitness Center  47.511663  19.055173
# 50            Gym / Fitness Center  47.512604  19.050000
# 51            Gym / Fitness Center  47.489930  19.061149
# 52            Gym / Fitness Center  47.505183  19.092904
# 53            Gym / Fitness Center  47.470829  19.083172
# 54            Gym / Fitness Center  47.494451  19.049471
# 55            Gym / Fitness Center  47.501760  19.039462
# 56            Gym / Fitness Center  47.493526  19.051981
# 57            Gym / Fitness Center  47.529621  19.150410
# 58            Gym / Fitness Center  47.509816  19.056108
# 59            Gym / Fitness Center  47.551200  19.072919
# 60            Gym / Fitness Center  47.502999  19.051942
# 61            Gym / Fitness Center  47.544313  19.073346
# 62            Gym / Fitness Center  47.406283  19.015868
# 63            Gym / Fitness Center  47.525315  19.064796
# 64            Gym / Fitness Center  47.527947  19.066436
# 65            Gym / Fitness Center  47.495558  19.076886
# 66            Gym / Fitness Center  47.518155  19.114575
# 67            Gym / Fitness Center  47.476093  19.068611
# 68            Gym / Fitness Center  47.502363  19.056501
# 69            Gym / Fitness Center  47.487419  19.063551
# 70            Gym / Fitness Center  47.494768  19.049050
# 71            Gym / Fitness Center  47.502013  19.048774
# 72            Gym / Fitness Center  47.460512  19.045739
# 73                 Conference Room  47.492252  19.050831
# 74                 Conference Room  47.505467  19.159598
# 75                 Conference Room  47.514064  19.058598
# 76                 Conference Room  47.498739  19.070873
# 77                 Conference Room  47.479287  19.068935
# 78                 Conference Room  47.456741  18.935946
# 79                 Conference Room  47.491492  19.081253
# 80                 Conference Room  47.470818  19.062943
# 81                 Conference Room  47.533220  19.059249
# 82                 Conference Room  47.537034  19.070936
# 83                 Conference Room  47.562093  19.055568
# 84                 College Library  47.492537  19.057242
# 85                 College Library  47.501188  19.049612
# 86                 College Library  47.501186  19.049579
# 87                         Library  47.497900  19.054249
# 88                 College Library  47.492876  19.061628
# 89                 College Library  47.492969  19.061665
# 90                         Library  47.483071  19.053922
# 91                 College Library  47.500655  19.067055
# 92                         Library  47.516056  19.036453
# 93                 College Library  47.489717  19.065528
# 94                 College Library  47.489231  19.065426
# 95                         Library  47.490290  19.053709
# 96                 College Library  47.533168  19.033647
# 97                 College Library  47.520944  18.990944
# 98                 College Library  47.489871  19.066621
# 99                 College Library  47.476457  18.991289
# 100                College Library  47.503402  19.076336
# 101                College Library  47.458923  18.958576
# 102                        Library  47.569683  18.899683

# %% [markdown]
# We save the dataset to a csv file:

# %%
DataFull.to_csv('DatFull.csv', index=False)

# %% [markdown]
# **We visualize the location of all the venues of interest**

# %%
full_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# set a color dictionnary
colors = {'Spa' : 'blue', 'Water Park' : 'blue', 'Pool' : 'blue', 'Vegetarian / Vegan Restaurant' : 'limegreen', 'Hungarian Restaurant' : 'red', 'Gym / Fitness Center' : 'black', 'Conference Room' : 'darkviolet', 'Library' : 'brown', 'College Library' : 'brown'}

DataFull.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["lng"]],
                                              radius=5, # define how big you want the circle markers to be
                                              color=False,
                                              fill=True,
                                              fill_color=colors[row['categories']],
                                              popup=row['categories'],
                                              fill_opacity=1)
                                             .add_to(full_map), axis=1)

# show map
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2.2 Building of the duration to airport dataset <a name="buildduration"></a>

# %% [markdown]
# **We first use geopy to get the latitude and longitude of the Budapest international airport**

# %%
address = 'Budapest Airport, Hungary'

geolocator = Nominatim(user_agent="bud_explorer")
location = geolocator.geocode(address)
latAIR = location.latitude
longAIR = location.longitude
print('The geograpical coordinate of Budapest Airport are {}, {}.'.format(latAIR, longAIR))
# Out:
# The geograpical coordinate of Budapest Airport are 47.433211, 19.262335.

# %% [markdown]
# **We use the Mapquest API to get the distance and duration from each venues of interest to the Budapest international airport**

# %% [markdown]
# Even if distance is not required, we search for this information in case area of interest to settle the headquarter would return the same trip duration to the airport. Distance may help in such cases.

# %% [markdown]
# We now run a hidden cell to give our mapquest key.

# %%
# @hidden_cell
mapquestkey='Feq0vnFrRt3o2LEMs5XAsO5fIYTF0G9Q'

# %% [markdown]
# As computing the distance and duration between each venue and the airport may take a while we use a function to print a progress bar.

# %%
import sys

def printProgressBar(i,max,postText):
    n_bar =10 #size of progress bar
    j= i/max
    sys.stdout.write('\r')
    sys.stdout.write(f"[{'=' * int(n_bar * j):{n_bar}s}] {int(100 * j)}%  {postText}")
    sys.stdout.flush()

# %% [markdown]
# And we run the queries:

# %%
dat = range(0,len(DataFull))
dfDuration = pd.DataFrame(columns=['distance', 'formattedTime'])

for i in dat:
    printProgressBar(i,len(DataFull),"Please wait!") # print progress bar
    loci = str(DataFull.loc[i,'lat'])+','+str(DataFull.loc[i,'lng'])
    locAIR = str(latAIR)+','+str(longAIR)
    loc = {"locations":[loci, locAIR]}
    url = 'https://www.mapquestapi.com/directions/v2/optimizedRoute?json={}&outFormat=json&key={}'.format(loc, mapquestkey)
    
    resultsDur = requests.get(url).json()
    
    # assign relevant part of JSON to venues
    duration = resultsDur['route']

    # tranform venues into a dataframe
    dfDur = pd.json_normalize(duration)
    dfDuration=dfDuration.append(dfDur[['distance', 'formattedTime']])
    
dfDuration.reset_index(drop=True, inplace=True)
distAirport=pd.concat([DataFull[['name']], dfDuration], axis=1)
distAirport.columns = ['from','Distance_to_airport_in_km','Duration_to_airport']
distAirport['Distance_to_airport_in_km'] = distAirport['Distance_to_airport_in_km'].mul(1.609344) #convert miles to km
distAirport
# Out:
# [========= ] 99%  Please wait!
#                                                   from  \
# 0                           Rudas Gyogyfurdo es Uszoda
# 1                   Szent Gellert Gyogyfurdo es Uszoda
# 2                    Szent Lukacs Gyogyfurdo es Uszoda
# 3                                    Dandar Gyogyfurdo
# 4                       Szechenyi Gyogyfurdo es Uszoda
# 5                                    Kiraly Gyogyfurdo
# 6                                Palatinus Strandfurdo
# 7                         Paskal Gyogy- es Strandfurdo
# 8                                    Romai Strandfurdo
# 9                                 Punkosdfurdoi Strand
# 10       Pesterzsebeti Jodos-Sos Gyogy- Es Strandfurdo
# 11                  Csillaghegyi Strandfurdo es Uszoda
# 12                                            VegaCity
# 13         Edeni Vegan - Kezmuves Vegetarianus Etterem
# 14                                Nemsuti Vega Etelbar
# 15                                          Vegan Love
# 16                                        Vegan Garden
# 17                                  Govinda Vega Sarok
# 18                                          Vegan king
# 19                                             Vegazzi
# 20                                   Veganeria Bisztro
# 21                                           VegaKucko
# 22                                            VegaRama
# 23                    Zen vegan es vegetarianus konyha
# 24                                     vegan food fest
# 25                                        Ganesha Vega
# 26                                    VegaLife etterem
# 27                       Madal Food - Vegan Restaurant
# 28                             Green Life Vegan Bakery
# 29                                827 Vegan Kitchen 2.
# 30                                         Greta Vegan
# 31                                Deli's Vegan Bisztro
# 32                              Keep Calm And Go Vegan
# 33                                          Las Vegans
# 34                                         Las Vegan's
# 35                                      Andreas Bistro
# 36                                  21 Magyar Vendeglo
# 37                               Horgasztanya Vendeglo
# 38                                   Alabardos Etterem
# 39                             Halaszbastya Restaurant
# 40                                      Tukory Etterem
# 41                                     Markus Vendeglo
# 42                           Muzeum Kavehaz es Etterem
# 43                                  Zold Kapu Vendeglo
# 44                                      Kehli Vendeglo
# 45                                F&M Fitness and More
# 46                                       Daily Fitness
# 47                               Get Fit River Fitness
# 48                                             Fitness
# 49                               Nova-Sun Fitness Club
# 50                                       Menta Fitness
# 51                             nr1 fitness -Kalvin ter
# 52                            Universum Fitness Recsei
# 53                            SCITEC Gold Fitness Club
# 54                  Fitness and Health Club by Mariott
# 55                                   CathaWahl Fitness
# 56                             Color Millenium Fitness
# 57                                    New York Fitness
# 58                               Life1 Nyugati Fitness
# 59                                Arena Fitness Center
# 60                                 Bank Center Fitness
# 61                      Fitness Works powered by Life1
# 62                                  Fitness Five & Gym
# 63                                   Gilda Max Fitness
# 64                                   John Reed Fitness
# 65                                  Livingroom Fitness
# 66                            Green Fitness and Beauty
# 67                            Castrum Fitness&Wellness
# 68                                      Fitness Center
# 69                                          4% FiTNESS
# 70                                    MB Spa & Fitness
# 71                                  Goldenlife Fitness
# 72                                    A Fitness Ujbuda
# 73                              Quince Conference Room
# 74                               CEU Conference Centre
# 75                           Avaya conference room 501
# 76                            Boscolo Conference Rooms
# 77                         Ibis Styles Conference Room
# 78                       Conference Room 1. Emelet 150
# 79                               REC Conference Centre
# 80                   Lm Ericsson Hilda Conference Area
# 81                AB InBev, Samlesbury Conference Room
# 82                        Chello Sport Conference Room
# 83                             Ustream Conference Room
# 84   ELTE Egyetemi Konyvtar es Leveltar / ELTE Univ...
# 85                 Central European University Library
# 86                                         CEU Library
# 87                                      Street Library
# 88     SEAS Library (Angol-amerikai Intezet konyvtara)
# 89                     CEU Library of Medieval Studies
# 90                          Budapest Christian Library
# 91                                         IBS Library
# 92   Semmelweis Orvostorteneti Konyvtar / Semmelwei...
# 93                                         HIK Library
# 94          Semmelweis University Central Library 7/24
# 95                      Orszagos Idegennyelvu Konyvtar
# 96   Obudai Egyetem - "Building - D" - Konyvtar - L...
# 97                                         IBS Library
# 98                Semmelweis Egyetem Kozponti Konyvtar
# 99                                   Spiritual Library
# 100         Hutyra Ferenc Konyvtar, Leveltar es Muzeum
# 101            Gr. Bercsenyi Zsuzsanna Varosi Konyvtar
# 102                                       Aisb Library
#
#      Distance_to_airport_in_km Duration_to_airport
# 0                    21.684301            00:24:08
# 1                    20.799162            00:23:35
# 2                    24.338109            00:29:37
# 3                    18.787482            00:20:08
# 4                    22.585534            00:25:20
# 5                    25.413151            00:27:43
# 6                    26.441522            00:29:48
# 7                    22.505066            00:26:37
# 8                    47.091015            00:36:15
# 9                    44.725279            00:32:55
# 10                   19.347534            00:20:56
# 11                   45.175895            00:34:13
# 12                   21.911219            00:24:42
# 13                   25.179796            00:27:17
# 14                   25.043002            00:30:28
# 15                   21.497617            00:24:27
# 16                   21.373698            00:25:04
# 17                   20.694554            00:23:31
# 18                   21.405885            00:24:29
# 19                   21.552335            00:24:57
# 20                   21.861329            00:25:28
# 21                   19.568014            00:21:29
# 22                   21.965936            00:24:05
# 23                   19.725729            00:21:13
# 24                   25.313372            00:28:59
# 25                   21.481524            00:23:03
# 26                   24.951269            00:30:17
# 27                   23.008791            00:28:03
# 28                   24.500653            00:28:52
# 29                   19.881836            00:21:46
# 30                   20.160252            00:22:24
# 31                   21.961108            00:24:04
# 32                   20.937565            00:23:10
# 33                   21.244950            00:23:53
# 34                   21.507273            00:24:37
# 35                   20.478902            00:22:55
# 36                   24.687337            00:30:14
# 37                   24.429842            00:25:23
# 38                   24.112801            00:29:54
# 39                   24.278564            00:30:16
# 40                   22.033529            00:25:34
# 41                   24.629401            00:29:38
# 42                   19.899539            00:21:44
# 43                   26.924325            00:30:25
# 44                   27.270334            00:30:49
# 45                   23.428830            00:27:16
# 46                   23.451361            00:27:18
# 47                   25.825143            00:28:59
# 48                   20.884457            00:23:19
# 49                   22.519551            00:26:40
# 50                   23.205131            00:28:06
# 51                   19.688714            00:21:34
# 52                   21.767987            00:24:49
# 53                   19.160850            00:20:37
# 54                   21.331855            00:24:37
# 55                   24.402483            00:25:20
# 56                   21.233685            00:24:16
# 57                   32.907866            00:23:55
# 58                   22.181588            00:25:49
# 59                   26.306337            00:28:32
# 60                   21.652114            00:25:09
# 61                   26.023092            00:28:41
# 62                   34.950124            00:25:51
# 63                   24.056474            00:27:59
# 64                   24.172347            00:26:54
# 65                   20.303484            00:22:52
# 66                   22.783483            00:25:23
# 67                   19.555139            00:21:34
# 68                   21.306105            00:24:19
# 69                   20.174736            00:22:25
# 70                   21.557163            00:24:07
# 71                   21.996514            00:26:07
# 72                   21.608662            00:22:35
# 73                   21.082406            00:23:41
# 74                   31.205180            00:25:05
# 75                   22.622549            00:26:10
# 76                   20.884457            00:23:19
# 77                   19.751479            00:21:19
# 78                   51.357386            00:37:44
# 79                   19.558358            00:21:26
# 80                   20.741225            00:22:10
# 81                   25.632022            00:28:55
# 82                   24.930348            00:27:40
# 83                   29.668257            00:33:45
# 84                   20.560979            00:22:51
# 85                   21.537851            00:24:54
# 86                   21.537851            00:24:54
# 87                   20.783068            00:23:03
# 88                   21.842017            00:24:36
# 89                   21.835579            00:24:36
# 90                   20.725132            00:23:24
# 91                   20.865145            00:24:05
# 92                   24.219018            00:29:16
# 93                   19.831946            00:21:41
# 94                   19.609857            00:21:16
# 95                   21.203107            00:23:55
# 96                   27.936602            00:32:16
# 97                   26.787531            00:33:09
# 98                   19.772400            00:21:28
# 99                   27.019276            00:34:05
# 100                  20.541667            00:22:32
# 101                  30.068983            00:33:41
# 102                  35.820779            00:43:56

# %% [markdown]
# We save the dataset to a csv file:

# %%
distAirport.to_csv('distAirport.csv', index=False)

# %% [markdown]
# **We now have the two datasets necessary to find the best place for the new headquarter: DataFull for the venues and distAirport for the distance and duration to the airport**

# %% [markdown]
# ## 3. Methodology <a name="methodology"></a>

# %% [markdown]
# We first display all the venues of interest using the **folium library** in order to **explore geospatial data** and observe their organisation in Budapest. We plot circles of a radius of 1km around each official bath in order to gain a better idea about the potential areas of interest for headquarter. Indeed, the headquarter should not be further than 1km from a bath. As official baths are spread at quite large distance from each other, as they are not numerous and as the startup founders gave it as the first criteria, we decided to first base our observation on this category of venue.
#
# As the headquarter should be surrounded by few (at least 6 of different given categories) venues, we perform a **cluster analysis** to identify clusters of venues where the HQ would be close enough to everything. We use **DBSCAN algorithm** as this algorithm does not require to set a number of clusters a priori and do not constrain the shape of the clusters. DBSCAN is performed with the **Scikit-learn library**. Clusters are built using the distance of each venue to the airport and the corresponding trip duration as well as using the location (latitude and longitude) of each venue.

# %% [markdown]
# ## 4. Results <a name="results"></a>

# %% [markdown]
# ### 4.1 Exploration of geospatial data <a name="geospatial"></a>

# %% [markdown]
# **We first explore the organisation of the venues using folium**

# %%
full_map = folium.Map(location=[latBUD, longBUD], zoom_start=11)

# set a color dictionnary
colors = {'Spa' : 'blue', 'Water Park' : 'blue', 'Pool' : 'blue', 'Vegetarian / Vegan Restaurant' : 'limegreen', 'Hungarian Restaurant' : 'red', 'Gym / Fitness Center' : 'black', 'Conference Room' : 'darkviolet', 'Library' : 'brown', 'College Library' : 'brown'}

DataFull.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["lng"]],
                                              radius=5, # define how big you want the circle markers to be
                                              color=False,
                                              fill=True,
                                              fill_color=colors[row['categories']],
                                              popup=folium.Popup(row['name'], parse_html=True),
                                              fill_opacity=0.6)
                                             .add_to(full_map), axis=1)

DataFullWater = DataFull[DataFull['categories'].isin(['Water Park', 'Pool', 'Spa']) ]
DataFullWater.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=1000,
                                        color='red',fill=False).add_to(full_map), axis=1)    

# show map
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From this map, we see that most baths are on Buda side (West of the Danube) of Budapest while most venues of interest are on Pest side (East of the Danube). Also, half of the bath do not have any venue of interest in their surrounding (i.e. at less than 1km). In order to meet the criteria of the startup, we can already see that the best place for the headquarter is very likely to be in the city center. The surroundings of the Gellért and Rudas baths seem to be good candidates. Lukács and Király baths areas may also be acceptable locations.

# %% [markdown]
# ### 4.2 Clustering of geospatial, distance and duration to airport data <a name="clustering"></a>

# %% [markdown]
# In order to reduce the number of possibilities and to include all the criteria given by the startup founders, we carry out a cluster analysis using DBSCAN on the latitude and longitude of each venue and their distance and trip duration to the airport.

# %% [markdown]
# **We first need to convert Python time format to float for use of duration data in clustering methods**

# %%
# Function to convert Python time format to float
def time_to_sec(time_str):
    return sum(x * int(t) for x, t in zip([1, 60, 3600], reversed(time_str.split(":"))))

# %%
HtoAir = distAirport['Duration_to_airport'].apply(time_to_sec)/60
dAir=pd.concat([distAirport['from'],distAirport['Distance_to_airport_in_km'], HtoAir], axis=1)
dAir.columns = ['from','Distance_to_airport_in_km','Duration_to_airport_in_minutes']

# %%
dAir.head()
# Out:
#                                  from  Distance_to_airport_in_km  \
# 0          Rudas Gyogyfurdo es Uszoda                  21.684301
# 1  Szent Gellert Gyogyfurdo es Uszoda                  20.799162
# 2   Szent Lukacs Gyogyfurdo es Uszoda                  24.338109
# 3                   Dandar Gyogyfurdo                  18.787482
# 4      Szechenyi Gyogyfurdo es Uszoda                  22.585534
#
#    Duration_to_airport_in_minutes
# 0                       24.133333
# 1                       23.583333
# 2                       29.616667
# 3                       20.133333
# 4                       25.333333

# %% [markdown]
# **We concatenate name, category and location data of each venue with their distance and trip duration to the airport**

# %%
dataClust=pd.concat([DataFull['name'],DataFull['categories'],dAir['Distance_to_airport_in_km'],dAir['Duration_to_airport_in_minutes'],DataFull['lat'],DataFull['lng']], axis=1)
dataClust.head()
# Out:
#                                  name categories  Distance_to_airport_in_km  \
# 0          Rudas Gyogyfurdo es Uszoda        Spa                  21.684301
# 1  Szent Gellert Gyogyfurdo es Uszoda        Spa                  20.799162
# 2   Szent Lukacs Gyogyfurdo es Uszoda        Spa                  24.338109
# 3                   Dandar Gyogyfurdo        Spa                  18.787482
# 4      Szechenyi Gyogyfurdo es Uszoda        Spa                  22.585534
#
#    Duration_to_airport_in_minutes        lat        lng
# 0                       24.133333  47.489188  19.047761
# 1                       23.583333  47.483917  19.052256
# 2                       29.616667  47.517898  19.036682
# 3                       20.133333  47.476337  19.071061
# 4                       25.333333  47.518302  19.082394

# %% [markdown]
# **We run the DBSCAN analysis with an epsilon of 0.25 (best obtained results from several tests) and a minimum number of points per cluster of 6 (as at least 6 different categories of venue should be in the surrounding of the headquarter).**

# %%
sklearn.utils.check_random_state(1000)

Clus_dataSet = dataClust.iloc[:,2:6]
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.28, min_samples=6).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
dataClust["Clusters"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 

# A sample of clusters
dataClust
# Out:
#                                                   name  \
# 0                           Rudas Gyogyfurdo es Uszoda
# 1                   Szent Gellert Gyogyfurdo es Uszoda
# 2                    Szent Lukacs Gyogyfurdo es Uszoda
# 3                                    Dandar Gyogyfurdo
# 4                       Szechenyi Gyogyfurdo es Uszoda
# 5                                    Kiraly Gyogyfurdo
# 6                                Palatinus Strandfurdo
# 7                         Paskal Gyogy- es Strandfurdo
# 8                                    Romai Strandfurdo
# 9                                 Punkosdfurdoi Strand
# 10       Pesterzsebeti Jodos-Sos Gyogy- Es Strandfurdo
# 11                  Csillaghegyi Strandfurdo es Uszoda
# 12                                            VegaCity
# 13         Edeni Vegan - Kezmuves Vegetarianus Etterem
# 14                                Nemsuti Vega Etelbar
# 15                                          Vegan Love
# 16                                        Vegan Garden
# 17                                  Govinda Vega Sarok
# 18                                          Vegan king
# 19                                             Vegazzi
# 20                                   Veganeria Bisztro
# 21                                           VegaKucko
# 22                                            VegaRama
# 23                    Zen vegan es vegetarianus konyha
# 24                                     vegan food fest
# 25                                        Ganesha Vega
# 26                                    VegaLife etterem
# 27                       Madal Food - Vegan Restaurant
# 28                             Green Life Vegan Bakery
# 29                                827 Vegan Kitchen 2.
# 30                                         Greta Vegan
# 31                                Deli's Vegan Bisztro
# 32                              Keep Calm And Go Vegan
# 33                                          Las Vegans
# 34                                         Las Vegan's
# 35                                      Andreas Bistro
# 36                                  21 Magyar Vendeglo
# 37                               Horgasztanya Vendeglo
# 38                                   Alabardos Etterem
# 39                             Halaszbastya Restaurant
# 40                                      Tukory Etterem
# 41                                     Markus Vendeglo
# 42                           Muzeum Kavehaz es Etterem
# 43                                  Zold Kapu Vendeglo
# 44                                      Kehli Vendeglo
# 45                                F&M Fitness and More
# 46                                       Daily Fitness
# 47                               Get Fit River Fitness
# 48                                             Fitness
# 49                               Nova-Sun Fitness Club
# 50                                       Menta Fitness
# 51                             nr1 fitness -Kalvin ter
# 52                            Universum Fitness Recsei
# 53                            SCITEC Gold Fitness Club
# 54                  Fitness and Health Club by Mariott
# 55                                   CathaWahl Fitness
# 56                             Color Millenium Fitness
# 57                                    New York Fitness
# 58                               Life1 Nyugati Fitness
# 59                                Arena Fitness Center
# 60                                 Bank Center Fitness
# 61                      Fitness Works powered by Life1
# 62                                  Fitness Five & Gym
# 63                                   Gilda Max Fitness
# 64                                   John Reed Fitness
# 65                                  Livingroom Fitness
# 66                            Green Fitness and Beauty
# 67                            Castrum Fitness&Wellness
# 68                                      Fitness Center
# 69                                          4% FiTNESS
# 70                                    MB Spa & Fitness
# 71                                  Goldenlife Fitness
# 72                                    A Fitness Ujbuda
# 73                              Quince Conference Room
# 74                               CEU Conference Centre
# 75                           Avaya conference room 501
# 76                            Boscolo Conference Rooms
# 77                         Ibis Styles Conference Room
# 78                       Conference Room 1. Emelet 150
# 79                               REC Conference Centre
# 80                   Lm Ericsson Hilda Conference Area
# 81                AB InBev, Samlesbury Conference Room
# 82                        Chello Sport Conference Room
# 83                             Ustream Conference Room
# 84   ELTE Egyetemi Konyvtar es Leveltar / ELTE Univ...
# 85                 Central European University Library
# 86                                         CEU Library
# 87                                      Street Library
# 88     SEAS Library (Angol-amerikai Intezet konyvtara)
# 89                     CEU Library of Medieval Studies
# 90                          Budapest Christian Library
# 91                                         IBS Library
# 92   Semmelweis Orvostorteneti Konyvtar / Semmelwei...
# 93                                         HIK Library
# 94          Semmelweis University Central Library 7/24
# 95                      Orszagos Idegennyelvu Konyvtar
# 96   Obudai Egyetem - "Building - D" - Konyvtar - L...
# 97                                         IBS Library
# 98                Semmelweis Egyetem Kozponti Konyvtar
# 99                                   Spiritual Library
# 100         Hutyra Ferenc Konyvtar, Leveltar es Muzeum
# 101            Gr. Bercsenyi Zsuzsanna Varosi Konyvtar
# 102                                       Aisb Library
#
#                         categories  Distance_to_airport_in_km  \
# 0                              Spa                  21.684301
# 1                              Spa                  20.799162
# 2                              Spa                  24.338109
# 3                              Spa                  18.787482
# 4                              Spa                  22.585534
# 5                              Spa                  25.413151
# 6                       Water Park                  26.441522
# 7                       Water Park                  22.505066
# 8                             Pool                  47.091015
# 9                             Pool                  44.725279
# 10                            Pool                  19.347534
# 11                            Pool                  45.175895
# 12   Vegetarian / Vegan Restaurant                  21.911219
# 13   Vegetarian / Vegan Restaurant                  25.179796
# 14   Vegetarian / Vegan Restaurant                  25.043002
# 15   Vegetarian / Vegan Restaurant                  21.497617
# 16   Vegetarian / Vegan Restaurant                  21.373698
# 17   Vegetarian / Vegan Restaurant                  20.694554
# 18   Vegetarian / Vegan Restaurant                  21.405885
# 19   Vegetarian / Vegan Restaurant                  21.552335
# 20   Vegetarian / Vegan Restaurant                  21.861329
# 21   Vegetarian / Vegan Restaurant                  19.568014
# 22   Vegetarian / Vegan Restaurant                  21.965936
# 23   Vegetarian / Vegan Restaurant                  19.725729
# 24   Vegetarian / Vegan Restaurant                  25.313372
# 25   Vegetarian / Vegan Restaurant                  21.481524
# 26   Vegetarian / Vegan Restaurant                  24.951269
# 27   Vegetarian / Vegan Restaurant                  23.008791
# 28   Vegetarian / Vegan Restaurant                  24.500653
# 29   Vegetarian / Vegan Restaurant                  19.881836
# 30   Vegetarian / Vegan Restaurant                  20.160252
# 31   Vegetarian / Vegan Restaurant                  21.961108
# 32   Vegetarian / Vegan Restaurant                  20.937565
# 33   Vegetarian / Vegan Restaurant                  21.244950
# 34   Vegetarian / Vegan Restaurant                  21.507273
# 35            Hungarian Restaurant                  20.478902
# 36            Hungarian Restaurant                  24.687337
# 37            Hungarian Restaurant                  24.429842
# 38            Hungarian Restaurant                  24.112801
# 39            Hungarian Restaurant                  24.278564
# 40            Hungarian Restaurant                  22.033529
# 41            Hungarian Restaurant                  24.629401
# 42            Hungarian Restaurant                  19.899539
# 43            Hungarian Restaurant                  26.924325
# 44            Hungarian Restaurant                  27.270334
# 45            Gym / Fitness Center                  23.428830
# 46            Gym / Fitness Center                  23.451361
# 47            Gym / Fitness Center                  25.825143
# 48            Gym / Fitness Center                  20.884457
# 49            Gym / Fitness Center                  22.519551
# 50            Gym / Fitness Center                  23.205131
# 51            Gym / Fitness Center                  19.688714
# 52            Gym / Fitness Center                  21.767987
# 53            Gym / Fitness Center                  19.160850
# 54            Gym / Fitness Center                  21.331855
# 55            Gym / Fitness Center                  24.402483
# 56            Gym / Fitness Center                  21.233685
# 57            Gym / Fitness Center                  32.907866
# 58            Gym / Fitness Center                  22.181588
# 59            Gym / Fitness Center                  26.306337
# 60            Gym / Fitness Center                  21.652114
# 61            Gym / Fitness Center                  26.023092
# 62            Gym / Fitness Center                  34.950124
# 63            Gym / Fitness Center                  24.056474
# 64            Gym / Fitness Center                  24.172347
# 65            Gym / Fitness Center                  20.303484
# 66            Gym / Fitness Center                  22.783483
# 67            Gym / Fitness Center                  19.555139
# 68            Gym / Fitness Center                  21.306105
# 69            Gym / Fitness Center                  20.174736
# 70            Gym / Fitness Center                  21.557163
# 71            Gym / Fitness Center                  21.996514
# 72            Gym / Fitness Center                  21.608662
# 73                 Conference Room                  21.082406
# 74                 Conference Room                  31.205180
# 75                 Conference Room                  22.622549
# 76                 Conference Room                  20.884457
# 77                 Conference Room                  19.751479
# 78                 Conference Room                  51.357386
# 79                 Conference Room                  19.558358
# 80                 Conference Room                  20.741225
# 81                 Conference Room                  25.632022
# 82                 Conference Room                  24.930348
# 83                 Conference Room                  29.668257
# 84                 College Library                  20.560979
# 85                 College Library                  21.537851
# 86                 College Library                  21.537851
# 87                         Library                  20.783068
# 88                 College Library                  21.842017
# 89                 College Library                  21.835579
# 90                         Library                  20.725132
# 91                 College Library                  20.865145
# 92                         Library                  24.219018
# 93                 College Library                  19.831946
# 94                 College Library                  19.609857
# 95                         Library                  21.203107
# 96                 College Library                  27.936602
# 97                 College Library                  26.787531
# 98                 College Library                  19.772400
# 99                 College Library                  27.019276
# 100                College Library                  20.541667
# 101                College Library                  30.068983
# 102                        Library                  35.820779
#
#      Duration_to_airport_in_minutes        lat        lng  Clusters
# 0                         24.133333  47.489188  19.047761         0
# 1                         23.583333  47.483917  19.052256         0
# 2                         29.616667  47.517898  19.036682        -1
# 3                         20.133333  47.476337  19.071061        -1
# 4                         25.333333  47.518302  19.082394        -1
# 5                         27.716667  47.510608  19.038185        -1
# 6                         29.800000  47.529170  19.046946        -1
# 7                         26.616667  47.520571  19.127469        -1
# 8                         36.250000  47.574811  19.052087        -1
# 9                         32.916667  47.594627  19.067900        -1
# 10                        20.933333  47.435448  19.090965        -1
# 11                        34.216667  47.585979  19.042334        -1
# 12                        24.700000  47.491976  19.061325         0
# 13                        27.283333  47.505884  19.037015        -1
# 14                        30.466667  47.513872  19.048410        -1
# 15                        24.450000  47.482396  19.052456        -1
# 16                        25.066667  47.499686  19.062519         0
# 17                        23.516667  47.490787  19.056462         0
# 18                        24.483333  47.489668  19.055639         0
# 19                        24.950000  47.501194  19.059412         0
# 20                        25.466667  47.506752  19.055643         0
# 21                        21.483333  47.481136  19.066939        -1
# 22                        24.083333  47.476133  19.045657        -1
# 23                        21.216667  47.488925  19.060994         1
# 24                        28.983333  47.512537  19.058982        -1
# 25                        23.050000  47.477510  19.052621        -1
# 26                        30.283333  47.525104  19.039193        -1
# 27                        28.050000  47.507331  19.049167        -1
# 28                        28.866667  47.508634  19.026008        -1
# 29                        21.766667  47.489105  19.061041         1
# 30                        22.400000  47.490601  19.068232         1
# 31                        24.066667  47.475801  19.045647        -1
# 32                        23.166667  47.496265  19.069632        -1
# 33                        23.883333  47.476016  19.048882        -1
# 34                        24.616667  47.497118  19.062899         0
# 35                        22.916667  47.488275  19.057433         0
# 36                        30.233333  47.504124  19.031075        -1
# 37                        25.383333  47.501962  19.039235        -1
# 38                        29.900000  47.501725  19.032720        -1
# 39                        30.266667  47.502534  19.034489        -1
# 40                        25.566667  47.505113  19.052301         0
# 41                        29.633333  47.509562  19.025011        -1
# 42                        21.733333  47.492046  19.061596         1
# 43                        30.416667  47.537197  19.038154        -1
# 44                        30.816667  47.537900  19.043370        -1
# 45                        27.266667  47.489801  19.022896        -1
# 46                        27.300000  47.495484  19.028377        -1
# 47                        28.983333  47.527996  19.056998        -1
# 48                        23.316667  47.498743  19.070396        -1
# 49                        26.666667  47.511663  19.055173        -1
# 50                        28.100000  47.512604  19.050000        -1
# 51                        21.566667  47.489930  19.061149         1
# 52                        24.816667  47.505183  19.092904        -1
# 53                        20.616667  47.470829  19.083172        -1
# 54                        24.616667  47.494451  19.049471         0
# 55                        25.333333  47.501760  19.039462        -1
# 56                        24.266667  47.493526  19.051981         0
# 57                        23.916667  47.529621  19.150410        -1
# 58                        25.816667  47.509816  19.056108         0
# 59                        28.533333  47.551200  19.072919        -1
# 60                        25.150000  47.502999  19.051942         0
# 61                        28.683333  47.544313  19.073346        -1
# 62                        25.850000  47.406283  19.015868        -1
# 63                        27.983333  47.525315  19.064796        -1
# 64                        26.900000  47.527947  19.066436        -1
# 65                        22.866667  47.495558  19.076886        -1
# 66                        25.383333  47.518155  19.114575        -1
# 67                        21.566667  47.476093  19.068611        -1
# 68                        24.316667  47.502363  19.056501         0
# 69                        22.416667  47.487419  19.063551         1
# 70                        24.116667  47.494768  19.049050         0
# 71                        26.116667  47.502013  19.048774         0
# 72                        22.583333  47.460512  19.045739        -1
# 73                        23.683333  47.492252  19.050831         0
# 74                        25.083333  47.505467  19.159598        -1
# 75                        26.166667  47.514064  19.058598        -1
# 76                        23.316667  47.498739  19.070873        -1
# 77                        21.316667  47.479287  19.068935        -1
# 78                        37.733333  47.456741  18.935946        -1
# 79                        21.433333  47.491492  19.081253        -1
# 80                        22.166667  47.470818  19.062943        -1
# 81                        28.916667  47.533220  19.059249        -1
# 82                        27.666667  47.537034  19.070936        -1
# 83                        33.750000  47.562093  19.055568        -1
# 84                        22.850000  47.492537  19.057242         0
# 85                        24.900000  47.501188  19.049612         0
# 86                        24.900000  47.501186  19.049579         0
# 87                        23.050000  47.497900  19.054249        -1
# 88                        24.600000  47.492876  19.061628         0
# 89                        24.600000  47.492969  19.061665         0
# 90                        23.400000  47.483071  19.053922        -1
# 91                        24.083333  47.500655  19.067055         0
# 92                        29.266667  47.516056  19.036453        -1
# 93                        21.683333  47.489717  19.065528         1
# 94                        21.266667  47.489231  19.065426         1
# 95                        23.916667  47.490290  19.053709         0
# 96                        32.266667  47.533168  19.033647        -1
# 97                        33.150000  47.520944  18.990944        -1
# 98                        21.466667  47.489871  19.066621         1
# 99                        34.083333  47.476457  18.991289        -1
# 100                       22.533333  47.503402  19.076336        -1
# 101                       33.683333  47.458923  18.958576        -1
# 102                       43.933333  47.569683  18.899683        -1

# %% [markdown]
# **We visualize the clusters using folium**

# %%
# create map
map_clusters = folium.Map(location=[latBUD, longBUD], zoom_start=12)

# set color scheme for the clusters
x = np.arange(clusterNum)
ys = [i + x + (i*x)**2 for i in range(clusterNum)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = ['darkviolet', 'red', 'blue']

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dataClust['lat'], dataClust['lng'], dataClust['categories'], dataClust['Clusters']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Two clusters are identified (numbered 0 in blue and 1 in purple). Numerous venues have been classified as -1 (red points), showing that numerous venues couldn't be associated to a cluster. These venues are two far from each other and/or to the airport by car to be considered as being of interest in our case. The cluster 1 is spread close to Kálvin tér, while cluster 0 is spread on Belváros, Lipótváros and the surrounding of the Opera.

# %% [markdown]
# **We remove the venues of cluster -1 which can be considered as outliers. They are venues which does not have 6 neighbors in their close surrounding. Thus they are unlikely to be in an area meeting the criteria for the HQ.**

# %%
clusteredArea = dataClust[dataClust['Clusters'].isin([0, 1])]
clusteredArea.reset_index(inplace=True, drop=True)
clusteredArea
# Out:
#                                                  name  \
# 0                          Rudas Gyogyfurdo es Uszoda
# 1                  Szent Gellert Gyogyfurdo es Uszoda
# 2                                            VegaCity
# 3                                        Vegan Garden
# 4                                  Govinda Vega Sarok
# 5                                          Vegan king
# 6                                             Vegazzi
# 7                                   Veganeria Bisztro
# 8                    Zen vegan es vegetarianus konyha
# 9                                827 Vegan Kitchen 2.
# 10                                        Greta Vegan
# 11                                        Las Vegan's
# 12                                     Andreas Bistro
# 13                                     Tukory Etterem
# 14                          Muzeum Kavehaz es Etterem
# 15                            nr1 fitness -Kalvin ter
# 16                 Fitness and Health Club by Mariott
# 17                            Color Millenium Fitness
# 18                              Life1 Nyugati Fitness
# 19                                Bank Center Fitness
# 20                                     Fitness Center
# 21                                         4% FiTNESS
# 22                                   MB Spa & Fitness
# 23                                 Goldenlife Fitness
# 24                             Quince Conference Room
# 25  ELTE Egyetemi Konyvtar es Leveltar / ELTE Univ...
# 26                Central European University Library
# 27                                        CEU Library
# 28    SEAS Library (Angol-amerikai Intezet konyvtara)
# 29                    CEU Library of Medieval Studies
# 30                                        IBS Library
# 31                                        HIK Library
# 32         Semmelweis University Central Library 7/24
# 33                     Orszagos Idegennyelvu Konyvtar
# 34               Semmelweis Egyetem Kozponti Konyvtar
#
#                        categories  Distance_to_airport_in_km  \
# 0                             Spa                  21.684301
# 1                             Spa                  20.799162
# 2   Vegetarian / Vegan Restaurant                  21.911219
# 3   Vegetarian / Vegan Restaurant                  21.373698
# 4   Vegetarian / Vegan Restaurant                  20.694554
# 5   Vegetarian / Vegan Restaurant                  21.405885
# 6   Vegetarian / Vegan Restaurant                  21.552335
# 7   Vegetarian / Vegan Restaurant                  21.861329
# 8   Vegetarian / Vegan Restaurant                  19.725729
# 9   Vegetarian / Vegan Restaurant                  19.881836
# 10  Vegetarian / Vegan Restaurant                  20.160252
# 11  Vegetarian / Vegan Restaurant                  21.507273
# 12           Hungarian Restaurant                  20.478902
# 13           Hungarian Restaurant                  22.033529
# 14           Hungarian Restaurant                  19.899539
# 15           Gym / Fitness Center                  19.688714
# 16           Gym / Fitness Center                  21.331855
# 17           Gym / Fitness Center                  21.233685
# 18           Gym / Fitness Center                  22.181588
# 19           Gym / Fitness Center                  21.652114
# 20           Gym / Fitness Center                  21.306105
# 21           Gym / Fitness Center                  20.174736
# 22           Gym / Fitness Center                  21.557163
# 23           Gym / Fitness Center                  21.996514
# 24                Conference Room                  21.082406
# 25                College Library                  20.560979
# 26                College Library                  21.537851
# 27                College Library                  21.537851
# 28                College Library                  21.842017
# 29                College Library                  21.835579
# 30                College Library                  20.865145
# 31                College Library                  19.831946
# 32                College Library                  19.609857
# 33                        Library                  21.203107
# 34                College Library                  19.772400
#
#     Duration_to_airport_in_minutes        lat        lng  Clusters
# 0                        24.133333  47.489188  19.047761         0
# 1                        23.583333  47.483917  19.052256         0
# 2                        24.700000  47.491976  19.061325         0
# 3                        25.066667  47.499686  19.062519         0
# 4                        23.516667  47.490787  19.056462         0
# 5                        24.483333  47.489668  19.055639         0
# 6                        24.950000  47.501194  19.059412         0
# 7                        25.466667  47.506752  19.055643         0
# 8                        21.216667  47.488925  19.060994         1
# 9                        21.766667  47.489105  19.061041         1
# 10                       22.400000  47.490601  19.068232         1
# 11                       24.616667  47.497118  19.062899         0
# 12                       22.916667  47.488275  19.057433         0
# 13                       25.566667  47.505113  19.052301         0
# 14                       21.733333  47.492046  19.061596         1
# 15                       21.566667  47.489930  19.061149         1
# 16                       24.616667  47.494451  19.049471         0
# 17                       24.266667  47.493526  19.051981         0
# 18                       25.816667  47.509816  19.056108         0
# 19                       25.150000  47.502999  19.051942         0
# 20                       24.316667  47.502363  19.056501         0
# 21                       22.416667  47.487419  19.063551         1
# 22                       24.116667  47.494768  19.049050         0
# 23                       26.116667  47.502013  19.048774         0
# 24                       23.683333  47.492252  19.050831         0
# 25                       22.850000  47.492537  19.057242         0
# 26                       24.900000  47.501188  19.049612         0
# 27                       24.900000  47.501186  19.049579         0
# 28                       24.600000  47.492876  19.061628         0
# 29                       24.600000  47.492969  19.061665         0
# 30                       24.083333  47.500655  19.067055         0
# 31                       21.683333  47.489717  19.065528         1
# 32                       21.266667  47.489231  19.065426         1
# 33                       23.916667  47.490290  19.053709         0
# 34                       21.466667  47.489871  19.066621         1

# %% [markdown]
# Only 35 venues are remaining.

# %% [markdown]
# **We display the remaining points of interests**

# %%
# create map and display it
full_map = folium.Map(location=[latBUD, longBUD], zoom_start=13)

# set a color dictionnary
colors = {'Spa' : 'blue', 'Water Park' : 'blue', 'Pool' : 'blue', 'Vegetarian / Vegan Restaurant' : 'limegreen', 'Hungarian Restaurant' : 'red', 'Gym / Fitness Center' : 'black', 'Conference Room' : 'darkviolet', 'Library' : 'brown', 'College Library' : 'brown'}

clusteredArea.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["lng"]],
                                              radius=5, # define how big you want the circle markers to be
                                              color=False,
                                              fill=True,
                                              fill_color=colors[row['categories']],
                                              popup=folium.Popup(row['name'], parse_html=True),
                                              fill_opacity=1)
                                             .add_to(full_map), axis=1)

DataFullWater = clusteredArea[clusteredArea['categories'].isin(['Water Park', 'Pool', 'Spa']) ]
DataFullWater.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=1000,
                                        color='red',fill=False).add_to(full_map), axis=1)    

# show map
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We observe that both Gellért and Rudas baths have all required facilities in a radius of 1000m, but all in the other side of the Danube. On the side of most facilities (Pest side), both circle of 1000m radius crossed each other close to Kálvin tér. Kálvin tér is also an area where venues are clustered (see cluster 1). If the headquarter would be close to this area, collaborators would have access to both baths and to all other categories of venue. Therefore, this seems to be the good place for the headquarter.

# %% [markdown]
# ### 4.3 Visualization of the suggested area and description of venues accessibilities <a name="kalvin"></a>

# %% [markdown]
# **We first use geopy to get the coordinates of Kálvin tér.**

# %%
address = 'Kálvin tér, Budapest, Hungary'

geolocator = Nominatim(user_agent="bud_explorer")
location = geolocator.geocode(address)
latKalvin = location.latitude
longKalvin = location.longitude
print('The geograpical coordinate of Kálvin tér are {}, {}.'.format(latKalvin, longKalvin))
# Out:
# The geograpical coordinate of Kálvin tér are 47.489152149999995, 19.06170279927273.

# %% [markdown]
# **We search for the distance and duration of a trip by car from Kálvin tér to the airport.**

# %%
locKal = str(latKalvin)+','+str(longKalvin)
locAIR = str(latAIR)+','+str(longAIR)
loc = {"locations":[locKal, locAIR]}
url = 'https://www.mapquestapi.com/directions/v2/optimizedRoute?json={}&outFormat=json&key={}'.format(loc, mapquestkey)
print(url)

resultsDurKal = requests.get(url).json()
    
# assign relevant part of JSON to venues
durationKal = resultsDurKal['route']

# tranform venues into a dataframe
dfDurKal = pd.json_normalize(durationKal)

Kalvin = {'name': ['Kalvin Ter'], 'categories': ['Headquarter area'], 'Distance_to_airport_in_km': [dfDurKal.loc[0,'distance']*1.609344], 'Duration_to_airport_in_minutes': [time_to_sec(dfDurKal.loc[0,'formattedTime'])/60], 'lat': [latKalvin], 'lng': [longKalvin]}
dfKal = pd.DataFrame(data=Kalvin)
dfKal
# Out:
# https://www.mapquestapi.com/directions/v2/optimizedRoute?json={'locations': ['47.489152149999995,19.06170279927273', '47.433211,19.262335']}&outFormat=json&key=Feq0vnFrRt3o2LEMs5XAsO5fIYTF0G9Q
#          name        categories  Distance_to_airport_in_km  \
# 0  Kalvin Ter  Headquarter area                  20.110363
#
#    Duration_to_airport_in_minutes        lat        lng
# 0                       22.233333  47.489152  19.061703

# %% [markdown]
# Kálvin tér is located around 20km from the airport and it takes less than 23 minutes to reach the airport by car.

# %% [markdown]
# **We observe the accessible venues within a distance of 500m and 1km (as the crow flies) from Kálvin tér. We also display a circle showing an area of 700m and 1200m around Kálvin tér in order to take into consideration that the headquarter may be few meters from the exact position of Kálvin tér. We suggest to search for a real estate in an area of 200m of radius around Kálvin tér.**

# %%
# create map and display it
full_map = folium.Map(location=[latKalvin, longKalvin], zoom_start=14)

# set a color dictionnary
colors = {'Spa' : 'blue', 'Vegetarian / Vegan Restaurant' : 'limegreen', 'Hungarian Restaurant' : 'red', 'Gym / Fitness Center' : 'black', 'Conference Room' : 'darkviolet', 'Library' : 'brown', 'College Library' : 'brown'}

dfKal.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=200,
                                        color='darkred',
                                        fill=True,
                                        fill_opacity=0.4,
                                        popup='Best area for headquarter')
                                       .add_to(full_map), axis=1)

dfKal.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=500,
                                        color='tomato',
                                        fill=False,
                                        popup='500m from Kalvin Ter')
                                       .add_to(full_map), axis=1)

dfKal.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=700,
                                        color='lightcoral',
                                        fill=False,
                                        popup='Extension of 200m depending on the exact location of the HQ, so 700m from Kalvin ter')
                                       .add_to(full_map), axis=1)

dfKal.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=1000,
                                        color='tomato',
                                        fill=False,
                                        popup='1000m from Kalvin Ter')
                                       .add_to(full_map), axis=1)    

dfKal.apply(lambda row:folium.Circle(location=[row["lat"], row["lng"]],
                                        radius=1200,
                                        color='lightcoral',
                                        fill=False,
                                        popup='Extension of 200m depending on the exact location of the HQ, so 1200m from Kalvin ter')
                                       .add_to(full_map), axis=1)    

clusteredArea.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["lng"]],
                                              radius=5, # define how big you want the circle markers to be
                                              color=False,
                                              fill=True,
                                              fill_color=colors[row['categories']],
                                              popup=folium.Popup(row['name'], parse_html=True),
                                              fill_opacity=1)
                                             .add_to(full_map), axis=1)

# show map
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# If a real estate can be found at the direct vicinity of Kálvin tér:
# - Gellért bath, one of the famous official (thermal) bath from Budapest, will be less than 1km from the headquarter
# - Quince conference room will be less than 1km from the headquarter
# - 7 libraries will be less than 1km from the headquarter, 6 of them will be less than 500m away
# - 5 restaurants providing vegetarian or vegan food and 2 restaurants providing hungarian food will be less than 500m from the headquarter
# - 2 fitness centers will be less than 500m from the headquarter
#
# **Kálvin tér is therefore the best candidate, as it meets all the given criteria and even overpass them.**

# %% [markdown]
# ## 5. Discussion <a name="discussion"></a>

# %% [markdown]
# Our analysis shows that even if there are 12 **official (thermal) baths** in Budapest, they are very **far from the airport and/or isolated** without many venues in their surroundings. Both Gellért and Rudas baths could have been good candidates to be selected as the bath close to the headquarter. Howerever, they are both on the West side of the Danube while most of the required venues are located on the East side. Therefore, **this criteria in particular reduced drastically the candidate areas to host the new headquarter**.
#
# **Combining exploration of the geospatial data and clustering using DBSCAN algorithm**, we could eliminate venues which were too far or isolated to have a chance to satisfy the criteria. Based on the results of the maps description and of the clustering, the surrounding of **Kálvin tér have been identified as the best candidate area to host the new headquarter**.
#
# **Kálvin tér** is in **straight connection with the Gellért bath**, which would be located less than 1km from the HQ. Even if they are on different side of the Danube, they are connected with the Szabadság (Liberty) bridge. Going to the bath will be easy either walking or by public transportation. **One conference room and 7 libraries** are located less than 1km from Kálvin tér. Also, the collaborators will have the opportunity to choose between **5 vegetarian/vegan restaurants and 2 Hungarian restaurants**, located less than 500m from Kálvin tér. Fitness is also available with **2 fitness centers** located at less than 500m from Kálvin tér.
# Finally, Kálvin tér is one of the best location to go to the airport as it is on the main road joining the city center and the airport. Therefore, it will take **less than 23 minutes by car to reach the airport terminal**.
# Even if not requested, we can add that Kalvin Tér has metro station for 2 lines and is connected by this way to 3 train stations and to the bus station which goes to the airport by public transportation.
#
# As finding a real estate in the direct vicinity of Kálvin tér may be challenging, we also provided visualization for the venues accessibility considering that the HQ may be in an area of 200m of radius around Kálvin tér. In such case we recommend to locate the HQ rather in the west of Kálvin tér if it is desired to strictly keep a distance of less than 1km with an official bath.

# %% [markdown]
# ## 6. Conclusion <a name="conclusion"></a>

# %% [markdown]
# Using Foursquare and Mapquest API, it has been possible to gather the necessary data to response to the given problem. Mapping and description as well as clustering of geospatial and itinerary data allow to propose a solution to the startup founders. We could point the best area in Budapest which meet all the criteria they had to settle their new headquarter.
# In continuation, if they would like suggestion to optimize the organization of the time of their collaborators, we could search for the best venue for each category considering the duration to reach each of them from the HQ by walking and by public transportation.
